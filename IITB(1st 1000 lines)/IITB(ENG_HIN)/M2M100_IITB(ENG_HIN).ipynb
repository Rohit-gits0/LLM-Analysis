# %%
# !pip install transformers
# !pip install datasets transformers[sentencepiece] sacrebleu
# !pip install nltk
# !pip install torch
# !pip install bert_score
# !pip install torchtext
# !pip install language-tool-python
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.5)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)
# Collecting datasets
#   Downloading datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Collecting sacrebleu
#   Downloading sacrebleu-2.4.3-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: transformers[sentencepiece] in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.1.4)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.5)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.19.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.20.3)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.1.99)
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (4.9.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.7.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-2.21.0-py3-none-any.whl (527 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 31.8 MB/s eta 0:00:00
# Downloading sacrebleu-2.4.3-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 8.4 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.3 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 16.0 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.0 MB/s eta 0:00:00
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 15.5 MB/s eta 0:00:00
# Installing collected packages: xxhash, pyarrow, portalocker, dill, colorama, sacrebleu, multiprocess, datasets
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed colorama-0.4.6 datasets-2.21.0 dill-0.3.8 multiprocess-0.70.16 portalocker-2.10.1 pyarrow-17.0.0 sacrebleu-2.4.3 xxhash-3.5.0
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl (19.7 MB)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.20 nvidia-nvtx-cu12-12.1.105
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.3.1+cu121)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.1.4)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.42.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert_score) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.66.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert_score) (3.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert_score) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2024.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.0.0->bert_score) (12.6.20)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.23.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.19.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert_score) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert_score) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0.0->bert_score) (1.3.0)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 4.6 MB/s eta 0:00:00
# Installing collected packages: bert_score
# Successfully installed bert_score-0.3.13
# Requirement already satisfied: torchtext in /usr/local/lib/python3.10/dist-packages (0.18.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchtext) (4.66.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchtext) (2.32.3)
# Requirement already satisfied: torch>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from torchtext) (2.3.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchtext) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.3.0->torchtext) (12.6.20)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.3.0->torchtext) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.3.0->torchtext) (1.3.0)
# Collecting language-tool-python
#   Downloading language_tool_python-2.8.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (from language-tool-python) (24.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from language-tool-python) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from language-tool-python) (4.66.5)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from language-tool-python) (0.44.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->language-tool-python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->language-tool-python) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->language-tool-python) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->language-tool-python) (2024.7.4)
# Downloading language_tool_python-2.8.1-py3-none-any.whl (35 kB)
# Installing collected packages: language-tool-python
# Successfully installed language-tool-python-2.8.1

# %%
import pandas as pd
import numpy as np
from datasets import load_dataset
import tensorflow as tf
import torch

# %%
# Check if GPU is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
# Define dataset path
dataset_path = "cfilt/iitb-english-hindi"
train_dataset = load_dataset(dataset_path, split="train[:1000]")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/3.14k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/953 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/190M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/85.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1659083 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/520 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2507 [00:00<?, ? examples/s]

# %%
english_sentences = [item['en'] for item in train_dataset['translation']]
hindi_sentences = [item['hi'] for item in train_dataset['translation']]

# %%
from transformers import pipeline
pipe = pipeline("text2text-generation", model="facebook/m2m100_418M")

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("facebook/m2m100_418M")
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/m2m100_418M").to(device)
# Out:
# config.json:   0%|          | 0.00/908 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.94G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/233 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/298 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/3.71M [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.14k [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
translatedEngHin = []
for index, (eng, hin) in enumerate(zip(english_sentences, hindi_sentences)):
    encoded_en = tokenizer(eng, return_tensors="pt", padding=True, truncation=True).to(device)
    generated_tokens = model.generate(**encoded_en, forced_bos_token_id=tokenizer.get_lang_id("hi")).to(device)
    translation = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]
    print(f"Index: {index+1}\nEnglish: {eng}\nHindi (Original): {hin}\nHindi (Translated): {translation}\n")
    print("------------------------------")
    translatedEngHin.append(translation)

comparison = pd.DataFrame({'Original': english_sentences, 'Translated': translatedEngHin})
comparison.to_csv('/content/IITB_Translated_EngHin.csv', index=False)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# ------------------------------
# Index: 168
# English: _ Edit Bookmarks...
# Hindi (Original): पुस्तक चिह्न संपादित करें (_ E)...
# Hindi (Translated): संपादित करें Bookmarks...
#
# ------------------------------
# Index: 169
# English: Manage bookmarks.
# Hindi (Original): पुस्तक-चिह्नों को प्रबंधित करें।
# Hindi (Translated): किताबों का प्रबंधन।
#
# ------------------------------
# Index: 170
# English: Edit Bookmarks...
# Hindi (Original): पुस्तक चिह्नों को संपादित करें...
# Hindi (Translated): संपादित करें Bookmarks...
#
# ------------------------------
# Index: 171
# English: Title
# Hindi (Original): शीर्षक
# Hindi (Translated): शीर्षक
#
# ------------------------------
# Index: 172
# English: Application
# Hindi (Original): अनुप्रयोग
# Hindi (Translated): आवेदन
#
# ------------------------------
# Index: 173
# English: Path
# Hindi (Original): पथ
# Hindi (Translated): रास्ते
#
# ------------------------------
# Index: 174
# English: Add Bookmark...
# Hindi (Original): पुस्तक-चिह्न जोड़ें...
# Hindi (Translated): Bookmark के बारे में...
#
# ------------------------------
# Index: 175
# English: Title:
# Hindi (Original): शीर्षकः
# Hindi (Translated): शीर्षक :
#
# ------------------------------
# Index: 176
# English: Application:
# Hindi (Original): अनुप्रयोगः
# Hindi (Translated): अनुप्रयोग :
#
# ------------------------------
# Index: 177
# English: Path:
# Hindi (Original): पथः
# Hindi (Translated): मार्ग :
#
# ------------------------------
# Index: 178
# English: Plugin Errors
# Hindi (Original): प्लग-इन त्रुटियां
# Hindi (Translated): Plugin गलतियां
#
# ------------------------------
# Index: 179
# English: View
# Hindi (Original): दृश्य
# Hindi (Translated): दृश्य
#
# ------------------------------
# Index: 180
# English: No view
# Hindi (Original): कोई दृश्य नहीं है
# Hindi (Translated): कोई दृष्टि
#
# ------------------------------
# Index: 181
# English: _ Single plugins view
# Hindi (Original): एकल प्लग-इन दृश्य
# Hindi (Translated): एकल प्लगइन दृश्य
#
# ------------------------------
# Index: 182
# English: Plugin View
# Hindi (Original): प्लग-इन दृश्य
# Hindi (Translated): Plugin दृश्य
#
# ------------------------------
# Index: 183
# English: Plugin View (% d)
# Hindi (Original): प्लग-इन दृश्य (% d)
# Hindi (Translated): प्लगइन दृश्य (% डी)
#
# ------------------------------
# Index: 184
# English: _ New view...
# Hindi (Original): नया दृश्य...
# Hindi (Translated): नए दृष्टिकोण...
#
# ------------------------------
# Index: 185
# English: New View...
# Hindi (Original): नया दृश्य...
# Hindi (Translated): नए दृष्टिकोण...
#
# ------------------------------
# Index: 186
# English: _ File
# Hindi (Original): फाइल (F)
# Hindi (Translated): फ़ाइल
#
# ------------------------------
# Index: 187
# English: _ Edit
# Hindi (Original): संपादित करें
# Hindi (Translated): संपादित करें
#
# ------------------------------
# Index: 188
# English: _ Bookmarks
# Hindi (Original): पुस्तक-चिह्न संपादित करें (_ E)...
# Hindi (Translated): बुकमार्क
#
# ------------------------------
# Index: 189
# English: _ View
# Hindi (Original): दृश्य _ (V)
# Hindi (Translated): दृश्य
#
# ------------------------------
# Index: 190
# English: _ Help
# Hindi (Original): मदद
# Hindi (Translated): सहायता
#
# ------------------------------
# Index: 191
# English: Full name
# Hindi (Original): पूरा नाम
# Hindi (Translated): पूर्ण नाम
#
# ------------------------------
# Index: 192
# English: Key binding
# Hindi (Original): कुंजी बंधन
# Hindi (Translated): कुंजी बंधन
#
# ------------------------------
# Index: 193
# English: Content type
# Hindi (Original): विषय प्रकार
# Hindi (Translated): सामग्री प्रकार
#
# ------------------------------
# Index: 194
# English: Give your application an accessibility workout
# Hindi (Original): अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# Hindi (Translated): अपने आवेदन को एक पहुंच प्रशिक्षण दें
#
# ------------------------------
# Index: 195
# English: Accerciser Accessibility Explorer
# Hindi (Original): एक्सेर्साइसर पहुंचनीयता अन्वेषक
# Hindi (Translated): Accessibility Explorer के बारे में टिप्पणियाँ
#
# ------------------------------
# Index: 196
# English: The default plugin layout for the bottom panel
# Hindi (Original): निचले पटल के लिए डिफोल्ट प्लग-इन खाका
# Hindi (Translated): नीचे पैनल के लिए डिफ़ॉल्ट प्लगइन लेआउट
#
# ------------------------------
# Index: 197
# English: The default plugin layout for the top panel
# Hindi (Original): ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका
# Hindi (Translated): शीर्ष पैनल के लिए डिफ़ॉल्ट प्लगइन लेआउट
#
# ------------------------------
# Index: 198
# English: A list of plugins that are disabled by default
# Hindi (Original): उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# Hindi (Translated): उन प्लगइन्स की सूची जो डिफ़ॉल्ट रूप से अक्षम हैं
#
# ------------------------------
# Index: 199
# English: Highlight duration
# Hindi (Original): अवधि को हाइलाइट रकें
# Hindi (Translated): ध्यान देने की अवधि
#
# ------------------------------
# Index: 200
# English: The duration of the highlight box when selecting accessible nodes
# Hindi (Original): पहुंचनीय आसंधि (नोड) को चुनते समय हाइलाइट बक्से की अवधि
# Hindi (Translated): पहुंचने वाले नोड्स का चयन करते समय हाइलाइट बॉक्स की अवधि
#
# ------------------------------
# Index: 201
# English: Highlight border color
# Hindi (Original): सीमांत (बोर्डर) के रंग को हाइलाइट करें
# Hindi (Translated): सीमा का रंग उजागर करें
#
# ------------------------------
# Index: 202
# English: The color and opacity of the highlight border.
# Hindi (Original): हाइलाइट किए गए सीमांत का रंग और अपारदर्शिता।
# Hindi (Translated): रंग और उज्ज्वल सीमा का अवरोध।
#
# ------------------------------
# Index: 203
# English: Highlight fill color
# Hindi (Original): भराई के रंग को हाइलाइट करें
# Hindi (Translated): रंग भरें
#
# ------------------------------
# Index: 204
# English: The color and opacity of the highlight fill.
# Hindi (Original): हाइलाइट किया गया भराई का रंग और पारदर्शिता।
# Hindi (Translated): प्रकाश के रंग और अशुद्धता को भरें।
#
# ------------------------------
# Index: 205
# English: API Browser
# Hindi (Original): एपीआई विचरक
# Hindi (Translated): API ब्राउज़र
#
# ------------------------------
# Index: 206
# English: Browse the various methods of the current accessible
# Hindi (Original): इस समय जिसे प्राप्त किया गया हो, उसकी विभिन्न विधियों (मेथड) में विचरण करें
# Hindi (Translated): वर्तमान उपलब्ध के विभिन्न तरीकों का सर्वेक्षण करें
#
# ------------------------------
# Index: 207
# English: Hide private attributes
# Hindi (Original): निजी गुणों को छिपाएं
# Hindi (Translated): निजी गुणों को छिपाएं
#
# ------------------------------
# Index: 208
# English: Method
# Hindi (Original): विधि
# Hindi (Translated): विधि
#
# ------------------------------
# Index: 209
# English: Property
# Hindi (Original): गुणधर्म
# Hindi (Translated): संपत्ति
#
# ------------------------------
# Index: 210
# English: Value
# Hindi (Original): मान
# Hindi (Translated): मूल्य
#
# ------------------------------
# Index: 211
# English: IPython Console
# Hindi (Original): आईपाइथन कन्सोल
# Hindi (Translated): IPython कंसोल
#
# ------------------------------
# Index: 212
# English: Interactive console for manipulating currently selected accessible
# Hindi (Original): इस समय चुने गए एक्सेसेबेल से काम लेने के लिए अंतर्क्रियात्मक कन्सोल
# Hindi (Translated): इंटरैक्टिव कंसोल वर्तमान में चुने गए को संभालने के लिए उपलब्ध है
#
# ------------------------------
# Index: 213
# English: Event monitor
# Hindi (Original): घटना मानिटर
# Hindi (Translated): घटना निगरानी
#
# ------------------------------
# Index: 214
# English: _ Monitor Events
# Hindi (Original): घटनाओं को मानिटर करें (_ M)
# Hindi (Translated): घटनाओं का निरीक्षण
#
# ------------------------------
# Index: 215
# English: C _ lear Selection
# Hindi (Original): चुनाव को हटाएं (C _)
# Hindi (Translated): C _ सीखने का चयन
#
# ------------------------------
# Index: 216
# English: Everything
# Hindi (Original): सभी
# Hindi (Translated): सब कुछ
#
# ------------------------------
# Index: 217
# English: Selected application
# Hindi (Original): चुने गए अनुप्रयोग
# Hindi (Translated): चुने हुए आवेदन
#
# ------------------------------
# Index: 218
# English: Selected accessible
# Hindi (Original): चुने गए एक्सेसेबेल
# Hindi (Translated): उपलब्ध चुनें
#
# ------------------------------
# Index: 219
# English: Source
# Hindi (Original): स्रोत
# Hindi (Translated): स्रोत
#
# ------------------------------
# Index: 220
# English: Event Monitor
# Hindi (Original): घटना मानिटर
# Hindi (Translated): घटना निगरानी
#
# ------------------------------
# Index: 221
# English: Shows events as they occur from selected types and sources
# Hindi (Original): चुने गए प्रकारों और स्रोतों से घटनाएं जैसे-जैसे घटित होती हैं, उन्हें दर्शाता है
# Hindi (Translated): घटनाओं को प्रदर्शित करता है जैसे कि वे चुने हुए प्रकार और स्रोतों से होते हैं
#
# ------------------------------
# Index: 222
# English: Highlight last event entry
# Hindi (Original): अंतिम प्रविष्ट घटना को हाइलाइट करो
# Hindi (Translated): आखिरी घटना प्रविष्टि
#
# ------------------------------
# Index: 223
# English: Start / stop event recording
# Hindi (Original): घटना रेकोर्डिंग शुरू करो/रोको
# Hindi (Translated): Start/Stop Event रिकॉर्डिंग
#
# ------------------------------
# Index: 224
# English: Clear event log
# Hindi (Original): घटना रोजनामचा मिटाओ
# Hindi (Translated): स्पष्ट घटना लॉग
#
# ------------------------------
# Index: 225
# English: (no description)
# Hindi (Original): कोई विवरण नहीं
# Hindi (Translated): (कोई वर्णन नहीं)
#
# ------------------------------
# Index: 226
# English: Description
# Hindi (Original): वर्णन
# Hindi (Translated): विवरण
#
# ------------------------------
# Index: 227
# English: Show
# Hindi (Original): दिखाएं
# Hindi (Translated): शो
#
# ------------------------------
# Index: 228
# English: _ Accessible
# Hindi (Original): पहुंचनीय
# Hindi (Translated): - पहुंच
#
# ------------------------------
# Index: 229
# English: Perform action
# Hindi (Original): कार्रवाई संपन्न करें
# Hindi (Translated): कार्रवाई करें
#
# ------------------------------
# Index: 230
# English: Acti _ on
# Hindi (Original): कार्रवाई (_ o)
# Hindi (Translated): कार्रवाई पर
#
# ------------------------------
# Index: 231
# English: ID
# Hindi (Original): आईडी
# Hindi (Translated): आईडी
#
# ------------------------------
# Index: 232
# English: Toolkit
# Hindi (Original): औजार बक्सा
# Hindi (Translated): टॉयलेट
#
# ------------------------------
# Index: 233
# English: Version
# Hindi (Original): संस्करण
# Hindi (Translated): संस्करण
#
# ------------------------------
# Index: 234
# English: Ap _ plication
# Hindi (Original): अनुप्रयोग
# Hindi (Translated): एपी - प्लगइन
#
# ------------------------------
# Index: 235
# English: Col _ lection
# Hindi (Original): संग्रह
# Hindi (Translated): सील - सबक
#
# ------------------------------
# Index: 236
# English: 0, 0
# Hindi (Original): 0, 0
# Hindi (Translated): 0 0 0
#
# ------------------------------
# Index: 237
# English: Relative position
# Hindi (Original): सापेक्ष स्थिति
# Hindi (Translated): Relative स्थिति
#
# ------------------------------
# Index: 238
# English: Size
# Hindi (Original): आकार
# Hindi (Translated): आकार
#
# ------------------------------
# Index: 239
# English: WIDGET
# Hindi (Original): विडजेट
# Hindi (Translated): विडगेट
#
# ------------------------------
# Index: 240
# English: Layer
# Hindi (Original): स्तर
# Hindi (Translated): लेयर
#
# ------------------------------
# Index: 241
# English: MDI - Z - order
# Hindi (Original): एमडीआई-जेड-क्रम
# Hindi (Translated): MDI - Z - आदेश
#
# ------------------------------
# Index: 242
# English: Alpha
# Hindi (Original): अल्फा
# Hindi (Translated): अल्फा
#
# ------------------------------
# Index: 243
# English: Absolute position
# Hindi (Original): निरपेक्ष स्थिति
# Hindi (Translated): पूर्ण स्थिति
#
# ------------------------------
# Index: 244
# English: Co _ mponent
# Hindi (Original): घटक
# Hindi (Translated): Mponent के बारे में
#
# ------------------------------
# Index: 245
# English: Des _ ktop
# Hindi (Original): डेस्कटोप
# Hindi (Translated): क्यूटीओपी
#
# ------------------------------
# Index: 246
# English: Locale:
# Hindi (Original): स्थान-विशिष्टः
# Hindi (Translated): स्थानीय :
#
# ------------------------------
# Index: 247
# English: _ Document
# Hindi (Original): प्रलेख
# Hindi (Translated): दस्तावेज
#
# ------------------------------
# Index: 248
# English: Hyperlink
# Hindi (Original): हाइपरकड़ी
# Hindi (Translated): हाइपरलिंक
#
# ------------------------------
# Index: 249
# English: H _ ypertext
# Hindi (Original): हाइपरपाठ
# Hindi (Translated): H _ Yपरटेक्स्ट
#
# ------------------------------
# Index: 250
# English: Position
# Hindi (Original): स्थिति
# Hindi (Translated): स्थिति
#
# ------------------------------
# Index: 251
# English: Description
# Hindi (Original): वर्णन
# Hindi (Translated): विवरण
#
# ------------------------------
# Index: 252
# English: Locale
# Hindi (Original): स्थान-विशिष्ट
# Hindi (Translated): स्थानीय
#
# ------------------------------
# Index: 253
# English: _ Image
# Hindi (Original): छवि (_ I)
# Hindi (Translated): छवि
#
# ------------------------------
# Index: 254
# English: Lo _ gin Helper
# Hindi (Original): प्रवेश सहायक
# Hindi (Translated): जीन सहायक
#
# ------------------------------
# Index: 255
# English: Select All
# Hindi (Original): सभी चुनें
# Hindi (Translated): सभी चुनें
#
# ------------------------------
# Index: 256
# English: _ Selection
# Hindi (Original): चयन (_ S)
# Hindi (Translated): चुनें
#
# ------------------------------
# Index: 257
# English: St _ reamable Content
# Hindi (Original): प्रवाहित करनेयोग्य विषयवस्तु
# Hindi (Translated): सेंट - रीमबल सामग्री
#
# ------------------------------
# Index: 258
# English: Selected columns
# Hindi (Original): चुने गए स्तंभ
# Hindi (Translated): चुने हुए स्तंभ
#
# ------------------------------
# Index: 259
# English: Selected rows
# Hindi (Original): चुनी गई पंक्तियां
# Hindi (Translated): चुने हुए पंक्तियों
#
# ------------------------------
# Index: 260
# English: Columns
# Hindi (Original): स्तंभ
# Hindi (Translated): स्तंभ
#
# ------------------------------
# Index: 261
# English: Rows
# Hindi (Original): पंक्तियां
# Hindi (Translated): गुलाब
#
# ------------------------------
# Index: 262
# English: Table Information
# Hindi (Original): & lt; bgt; सारणी सूचनाlt;/bgt;
# Hindi (Translated): टेबल जानकारी
#
# ------------------------------
# Index: 263
# English: name (x, y)
# Hindi (Original): नाम (x, y)
# Hindi (Translated): नाम (X और Y)
#
# ------------------------------
# Index: 264
# English: Header:
# Hindi (Original): शीर्षकः
# Hindi (Translated): शीर्षक :
#
# ------------------------------
# Index: 265
# English: Extents:
# Hindi (Original): विस्तारः
# Hindi (Translated): विस्तार :
#
# ------------------------------
# Index: 266
# English: Row
# Hindi (Original): पंक्ति
# Hindi (Translated): रॉय
#
# ------------------------------
# Index: 267
# English: Column
# Hindi (Original): स्तंभ
# Hindi (Translated): स्तंभ
#
# ------------------------------
# Index: 268
# English: Selected Cell
# Hindi (Original): & lt; bgt; चुनी गई कोशिकाlt;/bgt;
# Hindi (Translated): चुने हुए सेल
#
# ------------------------------
# Index: 269
# English: _ Table
# Hindi (Original): सारणी (_ T)
# Hindi (Translated): टेबल
#
# ------------------------------
# Index: 270
# English: Offset
# Hindi (Original): ओफसेट
# Hindi (Translated): अपमान
#
# ------------------------------
# Index: 271
# English: Include defaults
# Hindi (Original): डिफोल्टों को शामिल करें
# Hindi (Translated): डिफ़ॉल्ट भी शामिल है
#
# ------------------------------
# Index: 272
# English: Te _ xt
# Hindi (Original): पाठ (_ x)
# Hindi (Translated): XT के लिए
#
# ------------------------------
# Index: 273
# English: Current value
# Hindi (Original): मौजूदा मान
# Hindi (Translated): वर्तमान मूल्य
#
# ------------------------------
# Index: 274
# English: Minimum increment
# Hindi (Original): न्यूनतम वृद्धि
# Hindi (Translated): न्यूनतम वृद्धि
#
# ------------------------------
# Index: 275
# English: Maximum value
# Hindi (Original): अधिकतम मान
# Hindi (Translated): अधिकतम मूल्य
#
# ------------------------------
# Index: 276
# English: Minimum value
# Hindi (Original): न्यूनतम मान
# Hindi (Translated): न्यूनतम मूल्य
#
# ------------------------------
# Index: 277
# English: Val _ ue
# Hindi (Original): मान
# Hindi (Translated): यूरोपीय
#
# ------------------------------
# Index: 278
# English: Interface Viewer
# Hindi (Original): अंतराफलक दर्शक
# Hindi (Translated): इंटरफ़ेस विज़र
#
# ------------------------------
# Index: 279
# English: Allows viewing of various interface properties
# Hindi (Original): अंतराफलक के विभिन्न गुणों को देखने देता है
# Hindi (Translated): विभिन्न इंटरफ़ेस गुणों को देखने की अनुमति देता है
#
# ------------------------------
# Index: 280
# English: (not implemented)
# Hindi (Original): (क्रियान्वित नहीं हुआ है)
# Hindi (Translated): (अवैध नहीं किया गया है)
#
# ------------------------------
# Index: 281
# English: Name
# Hindi (Original): नाम
# Hindi (Translated): नाम
#
# ------------------------------
# Index: 282
# English: URI
# Hindi (Original): यूआरआई
# Hindi (Translated): यूआरआई
#
# ------------------------------
# Index: 283
# English: Start
# Hindi (Original): प्रारंभ
# Hindi (Translated): शुरुआत
#
# ------------------------------
# Index: 284
# English: End
# Hindi (Original): अंत
# Hindi (Translated): अंत
#
# ------------------------------
# Index: 285
# English: Too many selectable children
# Hindi (Original): बहुत अधिक चयनीय शिशु हैं
# Hindi (Translated): बहुत सारे चुनने योग्य बच्चे
#
# ------------------------------
# Index: 286
# English: Quick Select
# Hindi (Original): तेज चुनाव
# Hindi (Translated): त्वरित चयन
#
# ------------------------------
# Index: 287
# English: Plugin with various methods of selecting accessibles quickly.
# Hindi (Original): प्लग-इन जिसमें हैं एक्सेसेबेलों को तेजी से चुनने के लिए कई विधियां
# Hindi (Translated): विभिन्न विधियों के साथ प्लगइन जल्दी से सुलभ चुनने के लिए।
#
# ------------------------------
# Index: 288
# English: Inspect last focused accessible
# Hindi (Original): अंतिम बार फोकस किए गए एक्सेसेबल को जांचें
# Hindi (Translated): अंतिम ध्यान केंद्रित पहुंचने की जांच करें
#
# ------------------------------
# Index: 289
# English: Inspect accessible under mouse
# Hindi (Original): माउस के अधीन जो एक्सेसेबल है, उसे जांचें
# Hindi (Translated): माउस के नीचे उपलब्ध निरीक्षण
#
# ------------------------------
# Index: 290
# English: Native
# Hindi (Original): वतनी
# Hindi (Translated): स्वदेशी
#
# ------------------------------
# Index: 291
# English: Dogtail
# Hindi (Original): श्वानपुच्छ
# Hindi (Translated): कुत्ते
#
# ------------------------------
# Index: 292
# English: LDTP
# Hindi (Original): एलडीटीपी
# Hindi (Translated): एलडीपी
#
# ------------------------------
# Index: 293
# English: Script Type
# Hindi (Original): लिपि प्रकार
# Hindi (Translated): स्क्रिप्ट प्रकार
#
# ------------------------------
# Index: 294
# English: Script Recorder
# Hindi (Original): लिपि रेकोर्डर
# Hindi (Translated): स्क्रिप्ट रिकॉर्ड
#
# ------------------------------
# Index: 295
# English: Creates dogtail style scripts
# Hindi (Original): श्वानपुच्छ शैली की लिपियां निर्मित करता है
# Hindi (Translated): Dogtail स्टाइल स्क्रिप्ट बनाता है
#
# ------------------------------
# Index: 296
# English: The current script will be lost.
# Hindi (Original): वर्तमान लिपि (स्क्रिप्ट) खो जाएगी।
# Hindi (Translated): वर्तमान स्क्रिप्ट खो दिया जाएगा।
#
# ------------------------------
# Index: 297
# English: Confirm clear
# Hindi (Original): मिटाने की पुष्टि करें
# Hindi (Translated): स्पष्ट रूप से पुष्टि
#
# ------------------------------
# Index: 298
# English: Sche _ ma:
# Hindi (Original): स्कीमाः
# Hindi (Translated): मई - मई :
#
# ------------------------------
# Index: 299
# English: V _ alidate
# Hindi (Original): सत्यापन
# Hindi (Translated): एलईडी
#
# ------------------------------
# Index: 300
# English: Idle
# Hindi (Original): खाली
# Hindi (Translated): आईडीएल
#
# ------------------------------
# Index: 301
# English: No description
# Hindi (Original): कोई विवरण नहीं
# Hindi (Translated): कोई विवरण नहीं
#
# ------------------------------
# Index: 302
# English: AT - SPI Validator
# Hindi (Original): एटी-एसपीआई सत्यापक
# Hindi (Translated): SPI Validator के बारे में
#
# ------------------------------
# Index: 303
# English: Validates application accessibility
# Hindi (Original): अनुप्रयोग की पहुंचनीयता का सत्यापन करता है
# Hindi (Translated): आवेदन की उपलब्धता की पुष्टि करें
#
# ------------------------------
# Index: 304
# English: Level
# Hindi (Original): स्तर
# Hindi (Translated): स्तर
#
# ------------------------------
# Index: 305
# English: Role
# Hindi (Original): भूमिका
# Hindi (Translated): भूमिका
#
# ------------------------------
# Index: 306
# English: Saving
# Hindi (Original): सहेज रहे हैं
# Hindi (Translated): बचत
#
# ------------------------------
# Index: 307
# English: Validating
# Hindi (Original): पुष्टि कर रहे हैं
# Hindi (Translated): सत्यापित
#
# ------------------------------
# Index: 308
# English: EXCEPT
# Hindi (Original): अपवाद
# Hindi (Translated): अपवाद
#
# ------------------------------
# Index: 309
# English: ERROR
# Hindi (Original): त्रुटि
# Hindi (Translated): गलती
#
# ------------------------------
# Index: 310
# English: WARN
# Hindi (Original): चेतावनी
# Hindi (Translated): रंगीन
#
# ------------------------------
# Index: 311
# English: INFO
# Hindi (Original): सूचना
# Hindi (Translated): जानकारी
#
# ------------------------------
# Index: 312
# English: DEBUG
# Hindi (Original): दोषमुक्त करें
# Hindi (Translated): डेब्यू
#
# ------------------------------
# Index: 313
# English: Basic
# Hindi (Original): मूल
# Hindi (Translated): आधार
#
# ------------------------------
# Index: 314
# English: Tests fundamental GUI application accessibility
# Hindi (Original): मूलभूत जीयूआई अनुप्रयोग पहुंचनीयता का परीक्षण करता है
# Hindi (Translated): GUI अनुप्रयोगों की मौलिक पहुंचता का परीक्षण
#
# ------------------------------
# Index: 315
# English: actionable% s is not focusable or selectable
# Hindi (Original): % s जिस पर कार्रवाई हो सकती है, वह न तो फोकस करने योग्य है न ही चयनीय
# Hindi (Translated): सक्रिय% s फोकस योग्य या चयन योग्य नहीं है
#
# ------------------------------
# Index: 316
# English: interactive% s is not actionable
# Hindi (Original): अंतर्क्रियात्मक% s कार्रवाई करने योग्य नहीं है
# Hindi (Translated): इंटरैक्टिव% एस कार्रवाई योग्य नहीं है
#
# ------------------------------
# Index: 317
# English: more than one focused widget
# Hindi (Original): एक से अधिक विडजेट फोकस में है
# Hindi (Translated): एक से अधिक केंद्रित विगेट
#
# ------------------------------
# Index: 318
# English: % s has no text interface
# Hindi (Original): % s का कोई पाठ अंतराफलक नहीं है
# Hindi (Translated): % s कोई पाठ इंटरफ़ेस नहीं है
#
# ------------------------------
# Index: 319
# English: % s index in parent does not match child index
# Hindi (Original): अभिभावक में% s सूची शिशु सूची सेमेल नहीं खाती
# Hindi (Translated): माता-पिता में % s सूचकांक बच्चों के सूचकांक के अनुरूप नहीं है
#
# ------------------------------
# Index: 320
# English: Missing reciprocal for% s relation
# Hindi (Original): % s संबंध के लिए अन्योन्य गायब है
# Hindi (Translated): एक-दूसरे के रिश्ते के लिए एक-दूसरे की कमी
#
# ------------------------------
# Index: 321
# English: % s missing name or label
# Hindi (Original): % s गायब नाम या सूचक
# Hindi (Translated): %s गायब नाम या लेबल
#
# ------------------------------
# Index: 322
# English: focusable% s has table interface, no selection interface
# Hindi (Original): फोकस योग्य% s में सारणी अंतराफलक है, कोई चयनीय अंतराफलक नहीं हैbutton has focused state without focusable state
# Hindi (Translated): Focusable% s टेबल इंटरफ़ेस है, कोई चयन इंटरफ़ेस नहीं है
#
# ------------------------------
# Index: 323
# English: % s has% s state without% s state
# Hindi (Original): % s में% s स्थिति है, पर उसके साथ% s स्थिति नहीं है
# Hindi (Translated): % s है% s राज्य के बिना% s राज्य
#
# ------------------------------
# Index: 324
# English: % s does not belong to a set
# Hindi (Original): % s किसी समुच्चय का सदस्य नहीं है
# Hindi (Translated): % s एक सेट में शामिल नहीं है
#
# ------------------------------
# Index: 325
# English: % (rolename) s index% (num) d does not match row and column
# Hindi (Original): % (rolename) s सूची% (num) d पंक्ति और स्तंभ से मेल नहीं खातेparent indexrow and column index
# Hindi (Translated): % (Rolename) s इंडेक्स% (num) d क्रम और स्तंभ के अनुरूप नहीं है
#
# ------------------------------
# Index: 326
# English: % (rolename) s parent index% (num1) d does not match row and column index% (num2) d
# Hindi (Original): % (rolename) s अभिभावक सूची% (num1) d पंक्ति और स्तंभ सूची% (num2) d से मेल नहीं खाते
# Hindi (Translated): % (rolename) s मातृ सूचकांक% (num1) d क्रम और स्तंभ सूचकांक% (num2) d के अनुरूप नहीं है
#
# ------------------------------
# Index: 327
# English: % s has no name or description
# Hindi (Original): % s का कोई नाम या विवरण नहीं
# Hindi (Translated): % s कोई नाम या वर्णन नहीं है
#
# ------------------------------
# Index: 328
# English: _ Preferences...
# Hindi (Original): पसंद (_ P)...
# Hindi (Translated): प्राथमिकताएं...
#
# ------------------------------
# Index: 329
# English: _ Contents
# Hindi (Original): विषय सूची (_ C)
# Hindi (Translated): - सामग्री
#
# ------------------------------
# Index: 330
# English: Accerciser could not see the applications on your desktop. You must enable desktop accessibility to fix this problem. Do you want to enable it now?
# Hindi (Original): एक्सेरसाइसर आपके डेस्कटोप में मौजूद अनुप्रयोग नहीं देख पाया। इस समस्या के समाधान के लिए आपको डेस्कटोप पहुंचनीयता को सक्रिय करना होगा। क्या आप इसे सक्रिय करना चाहते हैं?
# Hindi (Translated): Accerciser आपके डेस्कटॉप पर अनुप्रयोगों को नहीं देख सकता था. आपको इस समस्या को ठीक करने के लिए डेस्कटॉप पहुंच को सक्षम करना होगा. क्या आप इसे अब सक्षम करना चाहते हैं?
#
# ------------------------------
# Index: 331
# English: Note: Changes only take effect after logout.
# Hindi (Original): टिप्पणीः परिवर्तन सत्रांत (लोगआउट) के बाद ही प्रभाव में आएंगे।
# Hindi (Translated): नोट: परिवर्तन केवल लॉग इन के बाद लागू होते हैं।
#
# ------------------------------
# Index: 332
# English: Children
# Hindi (Original): शिशु
# Hindi (Translated): बच्चों
#
# ------------------------------
# Index: 333
# English: _ Refresh Registry
# Hindi (Original): पंजी ताजा करें (_ R)
# Hindi (Translated): रजिस्ट्री को ताज़ा करें
#
# ------------------------------
# Index: 334
# English: Refresh all
# Hindi (Original): सभी को ताजा करें
# Hindi (Translated): सभी को ताज़ा
#
# ------------------------------
# Index: 335
# English: Refresh _ Node
# Hindi (Original): आसंधि (नोड) को ताजा करें (_ N)
# Hindi (Translated): नॉड - नॉड
#
# ------------------------------
# Index: 336
# English: Refresh selected node 's children
# Hindi (Original): चुनी गई आसंधियों (नोड) के शिशुओं को ताजा करें
# Hindi (Translated): चयनित नोड्स के बच्चों को पुनर्जीवित करें
#
# ------------------------------
# Index: 337
# English: Component
# Hindi (Original): घटक
# Hindi (Translated): घटक
#
# ------------------------------
# Index: 338
# English: Task
# Hindi (Original): कार्य
# Hindi (Translated): कर्तव्य
#
# ------------------------------
# Index: 339
# English: Key
# Hindi (Original): कुंजी
# Hindi (Translated): कुंजी
#
# ------------------------------
# Index: 340
# English: Alt
# Hindi (Original): आल्ट
# Hindi (Translated): एलटी
#
# ------------------------------
# Index: 341
# English: Ctrl
# Hindi (Original): कंट्रोल
# Hindi (Translated): Ctrl के बारे में
#
# ------------------------------
# Index: 342
# English: Shift
# Hindi (Original): शिफ्ट
# Hindi (Translated): बदलाव
#
# ------------------------------
# Index: 343
# English: Top panel
# Hindi (Original): ऊपरी पटल
# Hindi (Translated): शीर्ष पैनल
#
# ------------------------------
# Index: 344
# English: Bottom panel
# Hindi (Original): निचला पटल
# Hindi (Translated): नीचे पैनल
#
# ------------------------------
# Index: 345
# English: accerciser Preferences
# Hindi (Original): एक्सेर्साइसर पसंद
# Hindi (Translated): अनुकूलन प्राथमिकताएं
#
# ------------------------------
# Index: 346
# English: Plugins
# Hindi (Original): प्लगइन्स
# Hindi (Translated): प्लगइन
#
# ------------------------------
# Index: 347
# English: Global Hotkeys
# Hindi (Original): सार्वत्रिक फटाफट कुंजियां
# Hindi (Translated): ग्लोबल हॉटकेज
#
# ------------------------------
# Index: 348
# English: Highlighting
# Hindi (Original): हाइलाइटन
# Hindi (Translated): उच्चारण
#
# ------------------------------
# Index: 349
# English: Highlight duration:
# Hindi (Original): हाइलाइट अवधिः
# Hindi (Translated): ध्यान देने की अवधि:
#
# ------------------------------
# Index: 350
# English: Border color:
# Hindi (Original): सीमांत रंगः
# Hindi (Translated): सीमा रंग :
#
# ------------------------------
# Index: 351
# English: The border color of the highlight box
# Hindi (Original): हाइलाइट बक्से का सीमांत रंग
# Hindi (Translated): उच्च प्रकाश बॉक्स की सीमा रंग
#
# ------------------------------
# Index: 352
# English: Fill color:
# Hindi (Original): भराई का रंगः
# Hindi (Translated): रंग भरें :
#
# ------------------------------
# Index: 353
# English: The fill color of the highlight box
# Hindi (Original): हाइलाइट बक्से का भराई रंग
# Hindi (Translated): हाइलाइट बॉक्स का रंग भरना
#
# ------------------------------
# Index: 354
# English: translator - credits
# Hindi (Original): रविशंकर श्रीवास्तव (raviratlami @yahoo. com) राजेश रंजन (rajeshkajha @yahoo. com) ल. बालसुब्रमण्यम (l. balasubramaniam @gmail. com)
# Hindi (Translated): अनुवादक - क्रेडिट
#
# ------------------------------
# Index: 355
# English: An interactive Python accessibility explorer
# Hindi (Original): एक अंतर्क्रियात्मक पाइथन पहुंचनीयता अन्वेषक
# Hindi (Translated): एक इंटरैक्टिव Python एक्सेसबिलिटी एक्सप्लोरर
#
# ------------------------------
# Index: 356
# English: accerciser Copyright © 2006, 2007 IBM Corporation (BSD)
# Hindi (Original): एक्सेर्साइसर सर्वाधिकार © 2006,2007 आईबीएम निगम (बीएसडी)
# Hindi (Translated): कॉपीराइट कॉपीराइट © 2006, 2007 IBM Corporation (BSD)
#
# ------------------------------
# Index: 357
# English: The New BSD License See the COPYING and NOTICE files for details.
# Hindi (Original): नया बीएसडी लाइसेन्स विवरण के लिए देखिए प्रतिलिपीकरण और सूचना फाइलें
# Hindi (Translated): नई बीएसडी लाइसेंस विवरण के लिए कॉपी और नोटिस फ़ाइलों को देखता है।
#
# ------------------------------
# Index: 358
# English: Web site
# Hindi (Original): जाल स्थल
# Hindi (Translated): WEB साइट
#
# ------------------------------
# Index: 359
# English: _ Add Bookmark...
# Hindi (Original): पसंद जोड़ें... (_ A)
# Hindi (Translated): Bookmark के बारे में...
#
# ------------------------------
# Index: 360
# English: Bookmark selected accessible.
# Hindi (Original): चुने गए एक्सेसेबलों को पुस्तक-चिह्नित करें
# Hindi (Translated): चुने हुए बुकमार्क उपलब्ध हैं
#
# ------------------------------
# Index: 361
# English: _ Edit Bookmarks...
# Hindi (Original): पुस्तक चिह्न संपादित करें (_ E)...
# Hindi (Translated): संपादित करें Bookmarks...
#
# ------------------------------
# Index: 362
# English: Manage bookmarks.
# Hindi (Original): पुस्तक-चिह्नों को प्रबंधित करें।
# Hindi (Translated): किताबों का प्रबंधन।
#
# ------------------------------
# Index: 363
# English: Edit Bookmarks...
# Hindi (Original): पुस्तक चिह्नों को संपादित करें...
# Hindi (Translated): संपादित करें Bookmarks...
#
# ------------------------------
# Index: 364
# English: Title
# Hindi (Original): शीर्षक
# Hindi (Translated): शीर्षक
#
# ------------------------------
# Index: 365
# English: Application
# Hindi (Original): अनुप्रयोग
# Hindi (Translated): आवेदन
#
# ------------------------------
# Index: 366
# English: Path
# Hindi (Original): पथ
# Hindi (Translated): रास्ते
#
# ------------------------------
# Index: 367
# English: Add Bookmark...
# Hindi (Original): पुस्तक-चिह्न जोड़ें...
# Hindi (Translated): Bookmark के बारे में...
#
# ------------------------------
# Index: 368
# English: Title:
# Hindi (Original): शीर्षकः
# Hindi (Translated): शीर्षक :
#
# ------------------------------
# Index: 369
# English: Application:
# Hindi (Original): अनुप्रयोगः
# Hindi (Translated): अनुप्रयोग :
#
# ------------------------------
# Index: 370
# English: Path:
# Hindi (Original): पथः
# Hindi (Translated): मार्ग :
#
# ------------------------------
# Index: 371
# English: Plugin Errors
# Hindi (Original): प्लग-इन त्रुटियां
# Hindi (Translated): Plugin गलतियां
#
# ------------------------------
# Index: 372
# English: View
# Hindi (Original): दृश्य
# Hindi (Translated): दृश्य
#
# ------------------------------
# Index: 373
# English: No view
# Hindi (Original): कोई दृश्य नहीं है
# Hindi (Translated): कोई दृष्टि
#
# ------------------------------
# Index: 374
# English: _ Single plugins view
# Hindi (Original): एकल प्लग-इन दृश्य
# Hindi (Translated): एकल प्लगइन दृश्य
#
# ------------------------------
# Index: 375
# English: Plugin View
# Hindi (Original): प्लग-इन दृश्य
# Hindi (Translated): Plugin दृश्य
#
# ------------------------------
# Index: 376
# English: Plugin View (% d)
# Hindi (Original): प्लग-इन दृश्य (% d)
# Hindi (Translated): प्लगइन दृश्य (% डी)
#
# ------------------------------
# Index: 377
# English: _ New view...
# Hindi (Original): नया दृश्य...
# Hindi (Translated): नए दृष्टिकोण...
#
# ------------------------------
# Index: 378
# English: New View...
# Hindi (Original): नया दृश्य...
# Hindi (Translated): नए दृष्टिकोण...
#
# ------------------------------
# Index: 379
# English: _ File
# Hindi (Original): फाइल (F)
# Hindi (Translated): फ़ाइल
#
# ------------------------------
# Index: 380
# English: _ Edit
# Hindi (Original): संपादित करें
# Hindi (Translated): संपादित करें
#
# ------------------------------
# Index: 381
# English: _ Bookmarks
# Hindi (Original): पुस्तक-चिह्न संपादित करें (_ E)...
# Hindi (Translated): बुकमार्क
#
# ------------------------------
# Index: 382
# English: _ View
# Hindi (Original): दृश्य _ (V)
# Hindi (Translated): दृश्य
#
# ------------------------------
# Index: 383
# English: _ Help
# Hindi (Original): मदद
# Hindi (Translated): सहायता
#
# ------------------------------
# Index: 384
# English: Full name
# Hindi (Original): पूरा नाम
# Hindi (Translated): पूर्ण नाम
#
# ------------------------------
# Index: 385
# English: Key binding
# Hindi (Original): कुंजी बंधन
# Hindi (Translated): कुंजी बंधन
#
# ------------------------------
# Index: 386
# English: Content type
# Hindi (Original): विषय प्रकार
# Hindi (Translated): सामग्री प्रकार
#
# ------------------------------
# Index: 387
# English: Accerciser
# Hindi (Original): एक्सेर्साइसर
# Hindi (Translated): सटीक
#
# ------------------------------
# Index: 388
# English: Give your application an accessibility workout
# Hindi (Original): अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# Hindi (Translated): अपने आवेदन को एक पहुंच प्रशिक्षण दें
#
# ------------------------------
# Index: 389
# English: Accerciser Accessibility Explorer
# Hindi (Original): एक्सेर्साइसर पहुंचनीयता अन्वेषक
# Hindi (Translated): Accessibility Explorer के बारे में टिप्पणियाँ
#
# ------------------------------
# Index: 390
# English: A list of plugins that are disabled by default
# Hindi (Original): उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# Hindi (Translated): उन प्लगइन्स की सूची जो डिफ़ॉल्ट रूप से अक्षम हैं
#
# ------------------------------
# Index: 391
# English: A list of plugins that are disabled by default.
# Hindi (Original): उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# Hindi (Translated): उन प्लगइन्स की एक सूची जो डिफ़ॉल्ट रूप से अक्षम हैं।
#
# ------------------------------
# Index: 392
# English: Highlight duration
# Hindi (Original): अवधि को हाइलाइट रकें
# Hindi (Translated): ध्यान देने की अवधि
#
# ------------------------------
# Index: 393
# English: The duration of the highlight box when selecting accessible nodes.
# Hindi (Original): पहुंचनीय आसंधि नोड को चुनते समय हाइलाइट बक्से की अवधि.
# Hindi (Translated): उपलब्ध नोड्स का चयन करते समय हाइलाइट बॉक्स की अवधि।
#
# ------------------------------
# Index: 394
# English: Highlight fill color
# Hindi (Original): भराई के रंग को हाइलाइट करें
# Hindi (Translated): रंग भरें
#
# ------------------------------
# Index: 395
# English: The color and opacity of the highlight fill.
# Hindi (Original): हाइलाइट किया गया भराई का रंग और पारदर्शिता।
# Hindi (Translated): प्रकाश के रंग और अशुद्धता को भरें।
#
# ------------------------------
# Index: 396
# English: Highlight border color
# Hindi (Original): सीमांत (बोर्डर) के रंग को हाइलाइट करें
# Hindi (Translated): सीमा का रंग उजागर करें
#
# ------------------------------
# Index: 397
# English: The color and opacity of the highlight border.
# Hindi (Original): हाइलाइट किए गए सीमांत का रंग और अपारदर्शिता।
# Hindi (Translated): रंग और उज्ज्वल सीमा का अवरोध।
#
# ------------------------------
# Index: 398
# English: The layout for the bottom panel
# Hindi (Original): नीचे के पैनल के लिए लेआउट
# Hindi (Translated): नीचे के पैनल के लिए लेआउट
#
# ------------------------------
# Index: 399
# English: The layout for the bottom panel pluginview.
# Hindi (Original): नीचे पैनल pluginview के लिए लेआउट.
# Hindi (Translated): नीचे दिए गए पैनल के लिए प्लगइन विज़ुअल।
#
# ------------------------------
# Index: 400
# English: The layout for the top panel
# Hindi (Original): ऊपरी पटल के लिए खाका
# Hindi (Translated): शीर्ष पैनल के लिए लेआउट
#
# ------------------------------
# Index: 401
# English: The layout for the top panel pluginview.
# Hindi (Original): शीर्ष पैनल pluginview के लिए लेआउट.
# Hindi (Translated): शीर्ष पैनल प्लगइनविजन के लिए लेआउट।
#
# ------------------------------
# Index: 402
# English: Single layout view
# Hindi (Original): एकल लेआउट दृश्य
# Hindi (Translated): एकल लेआउट दृश्य
#
# ------------------------------
# Index: 403
# English: Available new pluginviews
# Hindi (Original): नई pluginviews उपलब्ध है
# Hindi (Translated): नए प्लगइन उपलब्ध हैं
#
# ------------------------------
# Index: 404
# English: The default plugin layout for the top panel.
# Hindi (Original): ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका.
# Hindi (Translated): शीर्ष पैनल के लिए डिफ़ॉल्ट प्लगइन लेआउट।
#
# ------------------------------
# Index: 405
# English: API Browser
# Hindi (Original): एपीआई विचरक
# Hindi (Translated): API ब्राउज़र
#
# ------------------------------
# Index: 406
# English: Browse the various methods of the current accessible
# Hindi (Original): इस समय जिसे प्राप्त किया गया हो, उसकी विभिन्न विधियों (मेथड) में विचरण करें
# Hindi (Translated): वर्तमान उपलब्ध के विभिन्न तरीकों का सर्वेक्षण करें
#
# ------------------------------
# Index: 407
# English: Hide private attributes
# Hindi (Original): निजी गुणों को छिपाएं
# Hindi (Translated): निजी गुणों को छिपाएं
#
# ------------------------------
# Index: 408
# English: Method
# Hindi (Original): विधि
# Hindi (Translated): विधि
#
# ------------------------------
# Index: 409
# English: Property
# Hindi (Original): गुणधर्म
# Hindi (Translated): संपत्ति
#
# ------------------------------
# Index: 410
# English: Value
# Hindi (Original): मान
# Hindi (Translated): मूल्य
#
# ------------------------------
# Index: 411
# English: IPython Console
# Hindi (Original): आईपाइथन कन्सोल
# Hindi (Translated): IPython कंसोल
#
# ------------------------------
# Index: 412
# English: Interactive console for manipulating currently selected accessible
# Hindi (Original): इस समय चुने गए एक्सेसेबेल से काम लेने के लिए अंतर्क्रियात्मक कन्सोल
# Hindi (Translated): इंटरैक्टिव कंसोल वर्तमान में चुने गए को संभालने के लिए उपलब्ध है
#
# ------------------------------
# Index: 413
# English: Event monitor
# Hindi (Original): घटना मानिटर
# Hindi (Translated): घटना निगरानी
#
# ------------------------------
# Index: 414
# English: _ Monitor Events
# Hindi (Original): घटनाओं को मानिटर करें (_ M)
# Hindi (Translated): घटनाओं का निरीक्षण
#
# ------------------------------
# Index: 415
# English: C _ lear Selection
# Hindi (Original): चुनाव को हटाएं (C _)
# Hindi (Translated): C _ सीखने का चयन
#
# ------------------------------
# Index: 416
# English: Everything
# Hindi (Original): सभी
# Hindi (Translated): सब कुछ
#
# ------------------------------
# Index: 417
# English: Selected application
# Hindi (Original): चुने गए अनुप्रयोग
# Hindi (Translated): चुने हुए आवेदन
#
# ------------------------------
# Index: 418
# English: Selected accessible
# Hindi (Original): चुने गए एक्सेसेबेल
# Hindi (Translated): उपलब्ध चुनें
#
# ------------------------------
# Index: 419
# English: Source
# Hindi (Original): स्रोत
# Hindi (Translated): स्रोत
#
# ------------------------------
# Index: 420
# English: Event Monitor
# Hindi (Original): घटना मानिटर
# Hindi (Translated): घटना निगरानी
#
# ------------------------------
# Index: 421
# English: Shows events as they occur from selected types and sources
# Hindi (Original): चुने गए प्रकारों और स्रोतों से घटनाएं जैसे-जैसे घटित होती हैं, उन्हें दर्शाता है
# Hindi (Translated): घटनाओं को प्रदर्शित करता है जैसे कि वे चुने हुए प्रकार और स्रोतों से होते हैं
#
# ------------------------------
# Index: 422
# English: Highlight last event entry
# Hindi (Original): अंतिम प्रविष्ट घटना को हाइलाइट करो
# Hindi (Translated): आखिरी घटना प्रविष्टि
#
# ------------------------------
# Index: 423
# English: Start / stop event recording
# Hindi (Original): घटना रेकोर्डिंग शुरू करो/रोको
# Hindi (Translated): Start/Stop Event रिकॉर्डिंग
#
# ------------------------------
# Index: 424
# English: Clear event log
# Hindi (Original): घटना रोजनामचा मिटाओ
# Hindi (Translated): स्पष्ट घटना लॉग
#
# ------------------------------
# Index: 425
# English: Child count
# Hindi (Original): बाल गणना
# Hindi (Translated): बच्चों की गिनती
#
# ------------------------------
# Index: 426
# English: Description
# Hindi (Original): वर्णन
# Hindi (Translated): विवरण
#
# ------------------------------
# Index: 427
# English: States
# Hindi (Original): राज्य
# Hindi (Translated): राज्यों
#
# ------------------------------
# Index: 428
# English: Attributes
# Hindi (Original): गुणधर्म
# Hindi (Translated): एथलीट
#
# ------------------------------
# Index: 429
# English: Show
# Hindi (Original): दिखाएं
# Hindi (Translated): शो
#
# ------------------------------
# Index: 430
# English: Relations
# Hindi (Original): संबंध
# Hindi (Translated): रिश्ते
#
# ------------------------------
# Index: 431
# English: _ Accessible
# Hindi (Original): पहुंचनीय
# Hindi (Translated): - पहुंच
#
# ------------------------------
# Index: 432
# English: Perform action
# Hindi (Original): कार्रवाई संपन्न करें
# Hindi (Translated): कार्रवाई करें
#
# ------------------------------
# Index: 433
# English: Acti _ on
# Hindi (Original): कार्रवाई (_ o)
# Hindi (Translated): कार्रवाई पर
#
# ------------------------------
# Index: 434
# English: ID
# Hindi (Original): आईडी
# Hindi (Translated): आईडी
#
# ------------------------------
# Index: 435
# English: Toolkit
# Hindi (Original): औजार बक्सा
# Hindi (Translated): टॉयलेट
#
# ------------------------------
# Index: 436
# English: Version
# Hindi (Original): संस्करण
# Hindi (Translated): संस्करण
#
# ------------------------------
# Index: 437
# English: Ap _ plication
# Hindi (Original): अनुप्रयोग
# Hindi (Translated): एपी - प्लगइन
#
# ------------------------------
# Index: 438
# English: Col _ lection
# Hindi (Original): संग्रह
# Hindi (Translated): सील - सबक
#
# ------------------------------
# Index: 439
# English: 0, 0
# Hindi (Original): 0, 0
# Hindi (Translated): 0 0 0
#
# ------------------------------
# Index: 440
# English: Relative position
# Hindi (Original): सापेक्ष स्थिति
# Hindi (Translated): Relative स्थिति
#
# ------------------------------
# Index: 441
# English: Size
# Hindi (Original): आकार
# Hindi (Translated): आकार
#
# ------------------------------
# Index: 442
# English: WIDGET
# Hindi (Original): विडजेट
# Hindi (Translated): विडगेट
#
# ------------------------------
# Index: 443
# English: Layer
# Hindi (Original): स्तर
# Hindi (Translated): लेयर
#
# ------------------------------
# Index: 444
# English: MDI - Z - order
# Hindi (Original): एमडीआई-जेड-क्रम
# Hindi (Translated): MDI - Z - आदेश
#
# ------------------------------
# Index: 445
# English: Alpha
# Hindi (Original): अल्फा
# Hindi (Translated): अल्फा
#
# ------------------------------
# Index: 446
# English: Absolute position
# Hindi (Original): निरपेक्ष स्थिति
# Hindi (Translated): पूर्ण स्थिति
#
# ------------------------------
# Index: 447
# English: Co _ mponent
# Hindi (Original): घटक
# Hindi (Translated): Mponent के बारे में
#
# ------------------------------
# Index: 448
# English: Des _ ktop
# Hindi (Original): डेस्कटोप
# Hindi (Translated): क्यूटीओपी
#
# ------------------------------
# Index: 449
# English: Locale:
# Hindi (Original): स्थान-विशिष्टः
# Hindi (Translated): स्थानीय :
#
# ------------------------------
# Index: 450
# English: _ Document
# Hindi (Original): प्रलेख
# Hindi (Translated): दस्तावेज
#
# ------------------------------
# Index: 451
# English: Hyperlink
# Hindi (Original): हाइपरकड़ी
# Hindi (Translated): हाइपरलिंक
#
# ------------------------------
# Index: 452
# English: H _ ypertext
# Hindi (Original): हाइपरपाठ
# Hindi (Translated): H _ Yपरटेक्स्ट
#
# ------------------------------
# Index: 453
# English: Position
# Hindi (Original): स्थिति
# Hindi (Translated): स्थिति
#
# ------------------------------
# Index: 454
# English: Locale
# Hindi (Original): स्थान-विशिष्ट
# Hindi (Translated): स्थानीय
#
# ------------------------------
# Index: 455
# English: _ Image
# Hindi (Original): छवि (_ I)
# Hindi (Translated): छवि
#
# ------------------------------
# Index: 456
# English: Lo _ gin Helper
# Hindi (Original): प्रवेश सहायक
# Hindi (Translated): जीन सहायक
#
# ------------------------------
# Index: 457
# English: Select All
# Hindi (Original): सभी चुनें
# Hindi (Translated): सभी चुनें
#
# ------------------------------
# Index: 458
# English: _ Selection
# Hindi (Original): चयन (_ S)
# Hindi (Translated): चुनें
#
# ------------------------------
# Index: 459
# English: St _ reamable Content
# Hindi (Original): प्रवाहित करनेयोग्य विषयवस्तु
# Hindi (Translated): सेंट - रीमबल सामग्री
#
# ------------------------------
# Index: 460
# English: Caption:
# Hindi (Original): शीर्षकः
# Hindi (Translated): कप्तान :
#
# ------------------------------
# Index: 461
# English: Summary:
# Hindi (Original): सारांशः
# Hindi (Translated): संक्षेप में :
#
# ------------------------------
# Index: 462
# English: Selected columns
# Hindi (Original): चुने गए स्तंभ
# Hindi (Translated): चुने हुए स्तंभ
#
# ------------------------------
# Index: 463
# English: Selected rows
# Hindi (Original): चुनी गई पंक्तियां
# Hindi (Translated): चुने हुए पंक्तियों
#
# ------------------------------
# Index: 464
# English: Columns
# Hindi (Original): स्तंभ
# Hindi (Translated): स्तंभ
#
# ------------------------------
# Index: 465
# English: Rows
# Hindi (Original): पंक्तियां
# Hindi (Translated): गुलाब
#
# ------------------------------
# Index: 466
# English: Table Information
# Hindi (Original): सारणी सूचना
# Hindi (Translated): टेबल जानकारी
#
# ------------------------------
# Index: 467
# English: name (x, y)
# Hindi (Original): नाम (x, y)
# Hindi (Translated): नाम (X और Y)
#
# ------------------------------
# Index: 468
# English: Header:
# Hindi (Original): शीर्षकः
# Hindi (Translated): शीर्षक :
#
# ------------------------------
# Index: 469
# English: Extents:
# Hindi (Original): विस्तारः
# Hindi (Translated): विस्तार :
#
# ------------------------------
# Index: 470
# English: Row
# Hindi (Original): पंक्ति
# Hindi (Translated): रॉय
#
# ------------------------------
# Index: 471
# English: Column
# Hindi (Original): स्तंभ
# Hindi (Translated): स्तंभ
#
# ------------------------------
# Index: 472
# English: Selected Cell
# Hindi (Original): चुनी गई कोशिका
# Hindi (Translated): चुने हुए सेल
#
# ------------------------------
# Index: 473
# English: _ Table
# Hindi (Original): सारणी (_ T)
# Hindi (Translated): टेबल
#
# ------------------------------
# Index: 474
# English: Offset
# Hindi (Original): ओफसेट
# Hindi (Translated): अपमान
#
# ------------------------------
# Index: 475
# English: Include defaults
# Hindi (Original): डिफोल्टों को शामिल करें
# Hindi (Translated): डिफ़ॉल्ट भी शामिल है
#
# ------------------------------
# Index: 476
# English: Start: 0
# Hindi (Original): प्रारंभ
# Hindi (Translated): शुरुआत : 0
#
# ------------------------------
# Index: 477
# English: End: 0
# Hindi (Original): अंतः 0
# Hindi (Translated): अंत : 0
#
# ------------------------------
# Index: 478
# English: Te _ xt
# Hindi (Original): पाठ (_ x)
# Hindi (Translated): XT के लिए
#
# ------------------------------
# Index: 479
# English: Current value
# Hindi (Original): मौजूदा मान
# Hindi (Translated): वर्तमान मूल्य
#
# ------------------------------
# Index: 480
# English: Minimum increment
# Hindi (Original): न्यूनतम वृद्धि
# Hindi (Translated): न्यूनतम वृद्धि
#
# ------------------------------
# Index: 481
# English: Maximum value
# Hindi (Original): अधिकतम मान
# Hindi (Translated): अधिकतम मूल्य
#
# ------------------------------
# Index: 482
# English: Minimum value
# Hindi (Original): न्यूनतम मान
# Hindi (Translated): न्यूनतम मूल्य
#
# ------------------------------
# Index: 483
# English: Val _ ue
# Hindi (Original): मान
# Hindi (Translated): यूरोपीय
#
# ------------------------------
# Index: 484
# English: unknown
# Hindi (Original): अज्ञात
# Hindi (Translated): अज्ञात
#
# ------------------------------
# Index: 485
# English: Interface Viewer
# Hindi (Original): अंतराफलक दर्शक
# Hindi (Translated): इंटरफ़ेस विज़र
#
# ------------------------------
# Index: 486
# English: Allows viewing of various interface properties
# Hindi (Original): अंतराफलक के विभिन्न गुणों को देखने देता है
# Hindi (Translated): विभिन्न इंटरफ़ेस गुणों को देखने की अनुमति देता है
#
# ------------------------------
# Index: 487
# English: (not implemented)
# Hindi (Original): (क्रियान्वित नहीं हुआ है)
# Hindi (Translated): (अवैध नहीं किया गया है)
#
# ------------------------------
# Index: 488
# English: Name
# Hindi (Original): नाम
# Hindi (Translated): नाम
#
# ------------------------------
# Index: 489
# English: URI
# Hindi (Original): यूआरआई
# Hindi (Translated): यूआरआई
#
# ------------------------------
# Index: 490
# English: Start
# Hindi (Original): प्रारंभ
# Hindi (Translated): शुरुआत
#
# ------------------------------
# Index: 491
# English: End
# Hindi (Original): अंत
# Hindi (Translated): अंत
#
# ------------------------------
# Index: 492
# English: Too many selectable children
# Hindi (Original): बहुत अधिक चयनीय शिशु हैं
# Hindi (Translated): बहुत सारे चुनने योग्य बच्चे
#
# ------------------------------
# Index: 493
# English: (Editable)
# Hindi (Original): (संशोधनीय) Start
# Hindi (Translated): (संपादित करें)
#
# ------------------------------
# Index: 494
# English: Start:% d
# Hindi (Original): प्रारंभEnd
# Hindi (Translated): प्रारंभ:% डी
#
# ------------------------------
# Index: 495
# English: Quick Select
# Hindi (Original): तेज चुनाव
# Hindi (Translated): त्वरित चयन
#
# ------------------------------
# Index: 496
# ...
# Hindi (Original): (संशोधनीय)
# Hindi (Translated): (संपादित करें)
#
# ------------------------------
# Index: 904
# English: Quick Select
# Hindi (Original): तेज चुनाव
# Hindi (Translated): त्वरित चयन
#
# ------------------------------
# Index: 905
# English: Plugin with various methods of selecting accessibles quickly.
# Hindi (Original): प्लग-इन जिसमें हैं एक्सेसेबेलों को तेजी से चुनने के लिए कई विधियां
# Hindi (Translated): विभिन्न विधियों के साथ प्लगइन जल्दी से सुलभ चुनने के लिए।
#
# ------------------------------
# Index: 906
# English: Inspect last focused accessible
# Hindi (Original): अंतिम बार फोकस किए गए एक्सेसेबल को जांचें
# Hindi (Translated): अंतिम ध्यान केंद्रित पहुंचने की जांच करें
#
# ------------------------------
# Index: 907
# English: Inspect accessible under mouse
# Hindi (Original): माउस के अधीन जो एक्सेसेबल है, उसे जांचें
# Hindi (Translated): माउस के नीचे उपलब्ध निरीक्षण
#
# ------------------------------
# Index: 908
# English: Sche _ ma:
# Hindi (Original): स्कीमाः
# Hindi (Translated): मई - मई :
#
# ------------------------------
# Index: 909
# English: V _ alidate
# Hindi (Original): सत्यापन
# Hindi (Translated): एलईडी
#
# ------------------------------
# Index: 910
# English: Idle
# Hindi (Original): खाली
# Hindi (Translated): आईडीएल
#
# ------------------------------
# Index: 911
# English: No description
# Hindi (Original): कोई विवरण नहीं
# Hindi (Translated): कोई विवरण नहीं
#
# ------------------------------
# Index: 912
# English: AT - SPI Validator
# Hindi (Original): एटी-एसपीआई सत्यापक
# Hindi (Translated): SPI Validator के बारे में
#
# ------------------------------
# Index: 913
# English: Validates application accessibility
# Hindi (Original): अनुप्रयोग की पहुंचनीयता का सत्यापन करता है
# Hindi (Translated): आवेदन की उपलब्धता की पुष्टि करें
#
# ------------------------------
# Index: 914
# English: Level
# Hindi (Original): स्तर
# Hindi (Translated): स्तर
#
# ------------------------------
# Index: 915
# English: Role
# Hindi (Original): भूमिका
# Hindi (Translated): भूमिका
#
# ------------------------------
# Index: 916
# English: Saving
# Hindi (Original): सहेज रहे हैं
# Hindi (Translated): बचत
#
# ------------------------------
# Index: 917
# English: Validating
# Hindi (Original): पुष्टि कर रहे हैं
# Hindi (Translated): सत्यापित
#
# ------------------------------
# Index: 918
# English: EXCEPT
# Hindi (Original): अपवाद
# Hindi (Translated): अपवाद
#
# ------------------------------
# Index: 919
# English: ERROR
# Hindi (Original): त्रुटि
# Hindi (Translated): गलती
#
# ------------------------------
# Index: 920
# English: WARN
# Hindi (Original): चेतावनी
# Hindi (Translated): रंगीन
#
# ------------------------------
# Index: 921
# English: INFO
# Hindi (Original): सूचना
# Hindi (Translated): जानकारी
#
# ------------------------------
# Index: 922
# English: DEBUG
# Hindi (Original): दोषमुक्त करें
# Hindi (Translated): डेब्यू
#
# ------------------------------
# Index: 923
# English: Basic
# Hindi (Original): मूल
# Hindi (Translated): आधार
#
# ------------------------------
# Index: 924
# English: Tests fundamental GUI application accessibility
# Hindi (Original): मूलभूत जीयूआई अनुप्रयोग पहुंचनीयता का परीक्षण करता है
# Hindi (Translated): GUI अनुप्रयोगों की मौलिक पहुंचता का परीक्षण
#
# ------------------------------
# Index: 925
# English: actionable% s is not focusable or selectable
# Hindi (Original): % s जिस पर कार्रवाई हो सकती है, वह न तो फोकस करने योग्य है न ही चयनीय
# Hindi (Translated): सक्रिय% s फोकस योग्य या चयन योग्य नहीं है
#
# ------------------------------
# Index: 926
# English: interactive% s is not actionable
# Hindi (Original): अंतर्क्रियात्मक% s कार्रवाई करने योग्य नहीं है
# Hindi (Translated): इंटरैक्टिव% एस कार्रवाई योग्य नहीं है
#
# ------------------------------
# Index: 927
# English: more than one focused widget
# Hindi (Original): एक से अधिक विडजेट फोकस में है
# Hindi (Translated): एक से अधिक केंद्रित विगेट
#
# ------------------------------
# Index: 928
# English: % s has no text interface
# Hindi (Original): % s का कोई पाठ अंतराफलक नहीं है
# Hindi (Translated): % s कोई पाठ इंटरफ़ेस नहीं है
#
# ------------------------------
# Index: 929
# English: % s index in parent does not match child index
# Hindi (Original): अभिभावक में% s सूची शिशु सूची सेमेल नहीं खाती
# Hindi (Translated): माता-पिता में % s सूचकांक बच्चों के सूचकांक के अनुरूप नहीं है
#
# ------------------------------
# Index: 930
# English: Missing reciprocal for% s relation
# Hindi (Original): % s संबंध के लिए अन्योन्य गायब है
# Hindi (Translated): एक-दूसरे के रिश्ते के लिए एक-दूसरे की कमी
#
# ------------------------------
# Index: 931
# English: % s missing name or label
# Hindi (Original): % s गायब नाम या सूचक
# Hindi (Translated): %s गायब नाम या लेबल
#
# ------------------------------
# Index: 932
# English: focusable% s has a table interface, but not a selection interface
# Hindi (Original): फोकस योग्य% s में सारणी अंतराफलक है, लेकिन कोई चयनीय अंतराफलक नहीं हैbutton has focused state without focusable state
# Hindi (Translated): Focusable% s में एक तालिका इंटरफ़ेस है, लेकिन एक चयन इंटरफ़ेस नहीं है
#
# ------------------------------
# Index: 933
# English: % s has% s state without% s state
# Hindi (Original): % s में% s स्थिति है, पर उसके साथ% s स्थिति नहीं है
# Hindi (Translated): % s है% s राज्य के बिना% s राज्य
#
# ------------------------------
# Index: 934
# English: % s does not belong to a set
# Hindi (Original): % s किसी समुच्चय का सदस्य नहीं है
# Hindi (Translated): % s एक सेट में शामिल नहीं है
#
# ------------------------------
# Index: 935
# English: % (rolename) s index% (num) d does not match row and column
# Hindi (Original): % (rolename) s सूची% (num) d पंक्ति और स्तंभ से मेल नहीं खातेparent indexrow and column index
# Hindi (Translated): % (Rolename) s इंडेक्स% (num) d क्रम और स्तंभ के अनुरूप नहीं है
#
# ------------------------------
# Index: 936
# English: % (rolename) s parent index% (num1) d does not match row and column index% (num2) d
# Hindi (Original): % (rolename) s अभिभावक सूची% (num1) d पंक्ति और स्तंभ सूची% (num2) d से मेल नहीं खाते
# Hindi (Translated): % (rolename) s मातृ सूचकांक% (num1) d क्रम और स्तंभ सूचकांक% (num2) d के अनुरूप नहीं है
#
# ------------------------------
# Index: 937
# English: % s has no name or description
# Hindi (Original): % s का कोई नाम या विवरण नहीं
# Hindi (Translated): % s कोई नाम या वर्णन नहीं है
#
# ------------------------------
# Index: 938
# English: _ Preferences...
# Hindi (Original): पसंद (_ P)...
# Hindi (Translated): प्राथमिकताएं...
#
# ------------------------------
# Index: 939
# English: _ Contents
# Hindi (Original): विषय सूची (_ C)
# Hindi (Translated): - सामग्री
#
# ------------------------------
# Index: 940
# English: Accerciser could not see the applications on your desktop. You must enable desktop accessibility to fix this problem. Do you want to enable it now?
# Hindi (Original): एक्सेरसाइसर आपके डेस्कटोप में मौजूद अनुप्रयोग नहीं देख पाया। इस समस्या के समाधान के लिए आपको डेस्कटोप पहुंचनीयता को सक्रिय करना होगा। क्या आप इसे सक्रिय करना चाहते हैं?
# Hindi (Translated): Accerciser आपके डेस्कटॉप पर अनुप्रयोगों को नहीं देख सकता था. आपको इस समस्या को ठीक करने के लिए डेस्कटॉप पहुंच को सक्षम करना होगा. क्या आप इसे अब सक्षम करना चाहते हैं?
#
# ------------------------------
# Index: 941
# English: Note: Changes only take effect after logout.
# Hindi (Original): टिप्पणीः परिवर्तन सत्रांत (लोगआउट) के बाद ही प्रभाव में आएंगे।
# Hindi (Translated): नोट: परिवर्तन केवल लॉग इन के बाद लागू होते हैं।
#
# ------------------------------
# Index: 942
# English: < dead >
# Hindi (Original): <dead>
# Hindi (Translated): ‘मृत’
#
# ------------------------------
# Index: 943
# English: Children
# Hindi (Original): शिशु
# Hindi (Translated): बच्चों
#
# ------------------------------
# Index: 944
# English: _ Hide / Show Applications without children
# Hindi (Original): बच्चों के बिना अनुप्रयोग छिपाएँ/दिखाएँ (_ H)
# Hindi (Translated): _ छिपाएं / बच्चों के बिना एप्लिकेशन दिखाएं
#
# ------------------------------
# Index: 945
# English: _ Refresh Registry
# Hindi (Original): पंजी ताजा करें (_ R)
# Hindi (Translated): रजिस्ट्री को ताज़ा करें
#
# ------------------------------
# Index: 946
# English: Refresh all
# Hindi (Original): सभी को ताजा करें
# Hindi (Translated): सभी को ताज़ा
#
# ------------------------------
# Index: 947
# English: Refresh _ Node
# Hindi (Original): आसंधि (नोड) को ताजा करें (_ N)
# Hindi (Translated): नॉड - नॉड
#
# ------------------------------
# Index: 948
# English: Refresh selected node 's children
# Hindi (Original): चुनी गई आसंधियों (नोड) के शिशुओं को ताजा करें
# Hindi (Translated): चयनित नोड्स के बच्चों को पुनर्जीवित करें
#
# ------------------------------
# Index: 949
# English: Component
# Hindi (Original): घटक
# Hindi (Translated): घटक
#
# ------------------------------
# Index: 950
# English: Task
# Hindi (Original): कार्य
# Hindi (Translated): कर्तव्य
#
# ------------------------------
# Index: 951
# English: Key
# Hindi (Original): कुंजी
# Hindi (Translated): कुंजी
#
# ------------------------------
# Index: 952
# English: Alt
# Hindi (Original): आल्ट
# Hindi (Translated): एलटी
#
# ------------------------------
# Index: 953
# English: Ctrl
# Hindi (Original): कंट्रोल
# Hindi (Translated): Ctrl के बारे में
#
# ------------------------------
# Index: 954
# English: Shift
# Hindi (Original): शिफ्ट
# Hindi (Translated): बदलाव
#
# ------------------------------
# Index: 955
# English: Top panel
# Hindi (Original): ऊपरी पटल
# Hindi (Translated): शीर्ष पैनल
#
# ------------------------------
# Index: 956
# English: Bottom panel
# Hindi (Original): निचला पटल
# Hindi (Translated): नीचे पैनल
#
# ------------------------------
# Index: 957
# English: accerciser Preferences
# Hindi (Original): एक्सेर्साइसर पसंद
# Hindi (Translated): अनुकूलन प्राथमिकताएं
#
# ------------------------------
# Index: 958
# English: Plugins
# Hindi (Original): प्लगइन्स
# Hindi (Translated): प्लगइन
#
# ------------------------------
# Index: 959
# English: Global Hotkeys
# Hindi (Original): सार्वत्रिक फटाफट कुंजियां
# Hindi (Translated): ग्लोबल हॉटकेज
#
# ------------------------------
# Index: 960
# English: Highlighting
# Hindi (Original): हाइलाइटन
# Hindi (Translated): उच्चारण
#
# ------------------------------
# Index: 961
# English: Highlight duration:
# Hindi (Original): हाइलाइट अवधिः
# Hindi (Translated): ध्यान देने की अवधि:
#
# ------------------------------
# Index: 962
# English: Border color:
# Hindi (Original): सीमांत रंगः
# Hindi (Translated): सीमा रंग :
#
# ------------------------------
# Index: 963
# English: The border color of the highlight box
# Hindi (Original): हाइलाइट बक्से का सीमांत रंग
# Hindi (Translated): उच्च प्रकाश बॉक्स की सीमा रंग
#
# ------------------------------
# Index: 964
# English: Fill color:
# Hindi (Original): भराई का रंगः
# Hindi (Translated): रंग भरें :
#
# ------------------------------
# Index: 965
# English: The fill color of the highlight box
# Hindi (Original): हाइलाइट बक्से का भराई रंग
# Hindi (Translated): हाइलाइट बॉक्स का रंग भरना
#
# ------------------------------
# Index: 966
# English: translator - credits
# Hindi (Original): रविशंकर श्रीवास्तव (raviratlami @yahoo. com) राजेश रंजन (rajeshkajha @yahoo. com) ल. बालसुब्रमण्यम (l. balasubramaniam @gmail. com)
# Hindi (Translated): अनुवादक - क्रेडिट
#
# ------------------------------
# Index: 967
# English: An interactive Python accessibility explorer
# Hindi (Original): एक अंतर्क्रियात्मक पाइथन पहुंचनीयता अन्वेषक
# Hindi (Translated): एक इंटरैक्टिव Python एक्सेसबिलिटी एक्सप्लोरर
#
# ------------------------------
# Index: 968
# English: accerciser Copyright (c) 2006, 2007 IBM Corporation (BSD)
# Hindi (Original): एक्सेर्साइसर सर्वाधिकार (c) 2006,2007 आईबीएम निगम (बीएसडी)
# Hindi (Translated): कॉपीराइट कॉपीराइट (c) 2006, 2007 आईबीएम कॉर्पोरेशन (बीएसडी)
#
# ------------------------------
# Index: 969
# English: The New BSD License See the COPYING and NOTICE files for details.
# Hindi (Original): नया बीएसडी लाइसेन्स विवरण के लिए देखिए प्रतिलिपीकरण और सूचना फाइलें
# Hindi (Translated): नई बीएसडी लाइसेंस विवरण के लिए कॉपी और नोटिस फ़ाइलों को देखता है।
#
# ------------------------------
# Index: 970
# English: Web site
# Hindi (Original): जाल स्थल
# Hindi (Translated): WEB साइट
#
# ------------------------------
# Index: 971
# English: _ Add Bookmark...
# Hindi (Original): पसंद जोड़ें... (_ A)
# Hindi (Translated): Bookmark के बारे में...
#
# ------------------------------
# Index: 972
# English: Bookmark selected accessible.
# Hindi (Original): चुने गए एक्सेसेबलों को पुस्तक-चिह्नित करें
# Hindi (Translated): चुने हुए बुकमार्क उपलब्ध हैं
#
# ------------------------------
# Index: 973
# English: _ Edit Bookmarks...
# Hindi (Original): पुस्तक चिह्न संपादित करें (_ E)...
# Hindi (Translated): संपादित करें Bookmarks...
#
# ------------------------------
# Index: 974
# English: Manage bookmarks.
# Hindi (Original): पुस्तक-चिह्नों को प्रबंधित करें।
# Hindi (Translated): किताबों का प्रबंधन।
#
# ------------------------------
# Index: 975
# English: Edit Bookmarks...
# Hindi (Original): पुस्तक चिह्नों को संपादित करें...
# Hindi (Translated): संपादित करें Bookmarks...
#
# ------------------------------
# Index: 976
# English: Title
# Hindi (Original): शीर्षक
# Hindi (Translated): शीर्षक
#
# ------------------------------
# Index: 977
# English: Application
# Hindi (Original): अनुप्रयोग
# Hindi (Translated): आवेदन
#
# ------------------------------
# Index: 978
# English: Path
# Hindi (Original): पथ
# Hindi (Translated): रास्ते
#
# ------------------------------
# Index: 979
# English: Add Bookmark...
# Hindi (Original): पुस्तक-चिह्न जोड़ें...
# Hindi (Translated): Bookmark के बारे में...
#
# ------------------------------
# Index: 980
# English: Title:
# Hindi (Original): शीर्षकः
# Hindi (Translated): शीर्षक :
#
# ------------------------------
# Index: 981
# English: Application:
# Hindi (Original): अनुप्रयोगः
# Hindi (Translated): अनुप्रयोग :
#
# ------------------------------
# Index: 982
# English: Path:
# Hindi (Original): पथः
# Hindi (Translated): मार्ग :
#
# ------------------------------
# Index: 983
# English: Plugin Errors
# Hindi (Original): प्लग-इन त्रुटियांviewport
# Hindi (Translated): Plugin गलतियां
#
# ------------------------------
# Index: 984
# English: View
# Hindi (Original): दृश्य
# Hindi (Translated): दृश्य
#
# ------------------------------
# Index: 985
# English: No view
# Hindi (Original): कोई दृश्य नहीं है
# Hindi (Translated): कोई दृष्टि
#
# ------------------------------
# Index: 986
# English: _ Single plugins view
# Hindi (Original): एकल प्लग-इन दृश्य
# Hindi (Translated): एकल प्लगइन दृश्य
#
# ------------------------------
# Index: 987
# English: Plugin View
# Hindi (Original): प्लग-इन दृश्य
# Hindi (Translated): Plugin दृश्य
#
# ------------------------------
# Index: 988
# English: Plugin View (% d)
# Hindi (Original): प्लग-इन दृश्य (% d)
# Hindi (Translated): प्लगइन दृश्य (% डी)
#
# ------------------------------
# Index: 989
# English: _ New view...
# Hindi (Original): नया दृश्य... (_ N)
# Hindi (Translated): नए दृष्टिकोण...
#
# ------------------------------
# Index: 990
# English: New View...
# Hindi (Original): नया दृश्य...
# Hindi (Translated): नए दृष्टिकोण...
#
# ------------------------------
# Index: 991
# English: _ File
# Hindi (Original): फाइल (F)
# Hindi (Translated): फ़ाइल
#
# ------------------------------
# Index: 992
# English: _ Edit
# Hindi (Original): संपादित करेंmenu
# Hindi (Translated): संपादित करें
#
# ------------------------------
# Index: 993
# English: _ Bookmarks
# Hindi (Original): पसंद (_ B) menu
# Hindi (Translated): बुकमार्क
#
# ------------------------------
# Index: 994
# English: _ View
# Hindi (Original): दृश्य _ (V)
# Hindi (Translated): दृश्य
#
# ------------------------------
# Index: 995
# English: _ Help
# Hindi (Original): मदद
# Hindi (Translated): सहायता
#
# ------------------------------
# Index: 996
# English: Accerciser
# Hindi (Original): एक्सेर्साइसर
# Hindi (Translated): सटीक
#
# ------------------------------
# Index: 997
# English: Give your application an accessibility workout
# Hindi (Original): अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# Hindi (Translated): अपने आवेदन को एक पहुंच प्रशिक्षण दें
#
# ------------------------------
# Index: 998
# English: Accerciser Accessibility Explorer
# Hindi (Original): एक्सेर्साइसर पहुंचनीयता अन्वेषक
# Hindi (Translated): Accessibility Explorer के बारे में टिप्पणियाँ
#
# ------------------------------
# Index: 999
# English: A list of plugins that are disabled by default
# Hindi (Original): उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# Hindi (Translated): उन प्लगइन्स की सूची जो डिफ़ॉल्ट रूप से अक्षम हैं
#
# ------------------------------
# Index: 1000
# English: A list of plugins that are disabled by default.
# Hindi (Original): उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# Hindi (Translated): उन प्लगइन्स की एक सूची जो डिफ़ॉल्ट रूप से अक्षम हैं।
#
# ------------------------------

# %%
# BLEU Score
import nltk
from nltk.translate.bleu_score import corpus_bleu
references = [[hindi] for hindi in hindi_sentences]  # Create reference list of lists
candidates = translatedEngHin  # Model translations
bleu_score = corpus_bleu(references, candidates)
print(f"BLEU score: {bleu_score:.4f}")
# Out:
# BLEU score: 0.3636

# %%
# STS Score

# !pip install sentence-transformers

# STS Score using SentenceTransformer
from sentence_transformers import SentenceTransformer, util
import torch

# Load the pre-trained model
model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
model = model.to('cuda' if torch.cuda.is_available() else 'cpu')

# Encode the original Hindi sentences and the translated sentences
embeddings1 = model.encode(hindi_sentences, convert_to_tensor=True, device=model.device)
embeddings2 = model.encode(translatedEngHin, convert_to_tensor=True, device=model.device)

# Compute cosine similarities between the embeddings
cosine_scores = util.cos_sim(embeddings1, embeddings2)

# Calculate the average STS score
sts_score = cosine_scores.diag().mean().item()
print(f"STS score: {sts_score:.4f}")
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.42.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.3.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.3.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers) (12.6.20)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 13.9 MB/s eta 0:00:00
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-3.0.1
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.12k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# STS score: 0.7286

# %%
# CHRF Score

# !pip install sacrebleu
from sacrebleu.metrics import CHRF

# Initialize CHRF metric
chrf = CHRF(word_order=1)

# Calculate CHRF score
chrf_score = chrf.corpus_score(translatedEngHin, [hindi_sentences]).score
print(f"CHRF score: {chrf_score:.4f}")
# Out:
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.10/dist-packages (2.4.3)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2.10.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2024.5.15)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (1.26.4)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (4.9.4)
# CHRF score: 28.9848

# %%
# METEOR score

import nltk
from nltk.translate.meteor_score import meteor_score

# Download required NLTK data (if not already downloaded)
nltk.download('punkt')
nltk.download('wordnet')

# Tokenize the sentences if they're not already tokenized
hindi_sentences_tokenized = [nltk.word_tokenize(sent) for sent in hindi_sentences]
translatedEngHin_tokenized = [nltk.word_tokenize(sent) for sent in translatedEngHin]

# Calculate METEOR score
meteor_scores = [meteor_score([ref], hyp) for ref, hyp in zip(hindi_sentences_tokenized, translatedEngHin_tokenized)]
average_meteor_score = sum(meteor_scores) / len(meteor_scores)

print(f"METEOR score: {average_meteor_score:.4f}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# METEOR score: 0.2059

# %%
import nltk
from nltk.lm import KneserNeyInterpolated
from nltk.lm.preprocessing import padded_everygram_pipeline
from nltk.util import ngrams
import numpy as np

# Download necessary NLTK data
nltk.download('punkt')

def train_model(sentences, n=2):
    tokenized = [['<s>'] + list(map(str.lower, nltk.word_tokenize(sent))) + ['</s>'] for sent in sentences]
    train_data, padded_vocab = padded_everygram_pipeline(n, tokenized)
    model = KneserNeyInterpolated(n)
    model.fit(train_data, padded_vocab)
    return model

def calculate_perplexity(model, sentences, n=2):
    perplexities = []
    for sent in sentences:
        tokens = ['<s>'] + list(map(str.lower, nltk.word_tokenize(sent))) + ['</s>']
        test_data = list(ngrams(tokens, n))
        try:
            pp = model.perplexity(test_data)
            perplexities.append(pp)
        except ValueError:
            pass  # Skip sentences that cause errors
    return np.mean(perplexities) if perplexities else float('inf')

# Train models
hindi_model = train_model(hindi_sentences)
english_model = train_model(translatedEngHin)

# Calculate perplexities
hindi_perplexity = calculate_perplexity(hindi_model, hindi_sentences)
english_perplexity = calculate_perplexity(english_model, translatedEngHin)

print(f"Hindi Perplexity: {hindi_perplexity:.4f}")
print(f"Translated English Perplexity: {english_perplexity:.4f}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Hindi Perplexity: 11.6234
# Translated English Perplexity: 11.6886
