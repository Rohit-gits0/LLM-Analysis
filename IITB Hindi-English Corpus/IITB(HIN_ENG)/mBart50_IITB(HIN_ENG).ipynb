# %%
# !pip install transformers
# !pip install datasets transformers[sentencepiece] sacrebleu
# !pip install nltk
# !pip install torch
# !pip install bert_score
# !pip install torchtext
# !pip install language-tool-python
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.5)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)
# Collecting datasets
#   Downloading datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Collecting sacrebleu
#   Downloading sacrebleu-2.4.3-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: transformers[sentencepiece] in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.1.4)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.5)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.19.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.20.3)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.1.99)
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (4.9.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.7.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-2.21.0-py3-none-any.whl (527 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 38.1 MB/s eta 0:00:00
# Downloading sacrebleu-2.4.3-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 9.3 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.3 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 19.8 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.1 MB/s eta 0:00:00
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.2 MB/s eta 0:00:00
# Installing collected packages: xxhash, pyarrow, portalocker, dill, colorama, sacrebleu, multiprocess, datasets
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed colorama-0.4.6 datasets-2.21.0 dill-0.3.8 multiprocess-0.70.16 portalocker-2.10.1 pyarrow-17.0.0 sacrebleu-2.4.3 xxhash-3.5.0
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.4.0+cu121)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.1.4)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.42.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert_score) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.66.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert_score) (3.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert_score) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2024.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (2024.6.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.23.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.19.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert_score) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert_score) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0.0->bert_score) (1.3.0)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 5.5 MB/s eta 0:00:00
# Installing collected packages: bert_score
# Successfully installed bert_score-0.3.13
# Collecting torchtext
#   Downloading torchtext-0.18.0-cp310-cp310-manylinux1_x86_64.whl.metadata (7.9 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchtext) (4.66.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchtext) (2.32.3)
# Requirement already satisfied: torch>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from torchtext) (2.4.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchtext) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (2024.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.3.0->torchtext) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.3.0->torchtext) (1.3.0)
# Downloading torchtext-0.18.0-cp310-cp310-manylinux1_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 42.5 MB/s eta 0:00:00
# Installing collected packages: torchtext
# Successfully installed torchtext-0.18.0
# Collecting language-tool-python
#   Downloading language_tool_python-2.8.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (from language-tool-python) (24.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from language-tool-python) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from language-tool-python) (4.66.5)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from language-tool-python) (0.44.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->language-tool-python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->language-tool-python) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->language-tool-python) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->language-tool-python) (2024.7.4)
# Downloading language_tool_python-2.8.1-py3-none-any.whl (35 kB)
# Installing collected packages: language-tool-python
# Successfully installed language-tool-python-2.8.1

# %%
import pandas as pd
import numpy as np
from datasets import load_dataset
import tensorflow as tf
import torch

# %%
# Define dataset path
dataset_path = "cfilt/iitb-english-hindi"
train_dataset = load_dataset(dataset_path, split="train[:1000]")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/3.14k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/953 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/190M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/85.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1659083 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/520 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2507 [00:00<?, ? examples/s]

# %%
english_sentences = [item['en'] for item in train_dataset['translation']]
hindi_sentences = [item['hi'] for item in train_dataset['translation']]

# %%
import torch
from transformers import pipeline, MBartForConditionalGeneration, MBart50TokenizerFast

# Check if GPU is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# Initialize the translation pipeline and specify the device
pipe = pipeline("translation", model="facebook/mbart-large-50-many-to-many-mmt", device=0 if torch.cuda.is_available() else -1)

# Load the model and tokenizer, and move the model to the appropriate device
model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50-many-to-many-mmt").to(device)
tokenizer = MBart50TokenizerFast.from_pretrained("facebook/mbart-large-50-one-to-many-mmt")

# Initialize the translation pipeline with the model and tokenizer, specifying the device
translator = pipeline('translation', model=model, tokenizer=tokenizer, src_lang="hi_IN", tgt_lang='en_XX', max_length=400, device=0 if torch.cuda.is_available() else -1)
# Out:
# Using device: cuda
# tokenizer_config.json:   0%|          | 0.00/528 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/717 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.43k [00:00<?, ?B/s]

# %%
translatedHinEng = []
for (index, (hin, eng)) in enumerate(zip(hindi_sentences, english_sentences)):
    print(index+1)
    print("Hindi:", hin)
    prediction = translator(hin)
    translation = prediction[0]['translation_text']
    print("Translated: ", translation)
    print("Original: ", eng)
    print("------------------------------")
    translatedHinEng.append(translation)

comparison = pd.DataFrame({'Original': english_sentences, 'Translated': translatedHinEng})
comparison.to_csv('/content/IITB_Translated_EngHin.csv', index=False)
# Out:
# 1
# Hindi: अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# Translated:  Benefit your application from accessibility exercises
# Original:  Give your application an accessibility workout
# ------------------------------
# 2
# Hindi: एक्सेर्साइसर पहुंचनीयता अन्वेषक
# Translated:  Cursor Accessibility Explorer
# Original:  Accerciser Accessibility Explorer
# ------------------------------
# 3
# Hindi: निचले पटल के लिए डिफोल्ट प्लग-इन खाका
# Translated:  Default plug - in for bottom panel
# Original:  The default plugin layout for the bottom panel
# ------------------------------
# 4
# Hindi: ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका
# Translated:  Default plug - in for top panel
# Original:  The default plugin layout for the top panel
# ------------------------------
# 5
# Hindi: उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# Translated:  List of plugins that have been disabled by default
# Original:  A list of plugins that are disabled by default
# ------------------------------
# 6
# Hindi: अवधि को हाइलाइट रकें
# Translated:  Highlight period
# Original:  Highlight duration
# ------------------------------
# 7
# Hindi: पहुंचनीय आसंधि (नोड) को चुनते समय हाइलाइट बक्से की अवधि
# Translated:  Duration of the highlight box when selecting the accessible node
# Original:  The duration of the highlight box when selecting accessible nodes
# ------------------------------
# 8
# Hindi: सीमांत (बोर्डर) के रंग को हाइलाइट करें
# Translated:  Highlight border (boarder) color
# Original:  Highlight border color
# ------------------------------
# 9
# Hindi: हाइलाइट किए गए सीमांत का रंग और अपारदर्शिता।
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Translated:  The color and opacity of the highlighted border.
# Original:  The color and opacity of the highlight border.
# ------------------------------
# 10
# Hindi: भराई के रंग को हाइलाइट करें
# Translated:  Highlight fill color
# Original:  Highlight fill color
# ------------------------------
# 11
# Hindi: हाइलाइट किया गया भराई का रंग और पारदर्शिता।
# Translated:  The color and transparency of the highlighted filling.
# Original:  The color and opacity of the highlight fill.
# ------------------------------
# 12
# Hindi: एपीआई विचरक
# Translated:  API Switcher
# Original:  API Browser
# ------------------------------
# 13
# Hindi: इस समय जिसे प्राप्त किया गया हो, उसकी विभिन्न विधियों (मेथड) में विचरण करें
# Translated:  Navigate to the different methods (methods) of the time which has been received.
# Original:  Browse the various methods of the current accessible
# ------------------------------
# 14
# Hindi: निजी गुणों को छिपाएं
# Translated:  Hide private properties
# Original:  Hide private attributes
# ------------------------------
# 15
# Hindi: विधि
# Translated:  method
# Original:  Method
# ------------------------------
# 16
# Hindi: गुणधर्म
# Translated:  property
# Original:  Property
# ------------------------------
# 17
# Hindi: मान
# Translated:  value
# Original:  Value
# ------------------------------
# 18
# Hindi: आईपाइथन कन्सोल
# Translated:  iPython console
# Original:  IPython Console
# ------------------------------
# 19
# Hindi: इस समय चुने गए एक्सेसेबेल से काम लेने के लिए अंतर्क्रियात्मक कन्सोल
# Translated:  Interactive console to work with the currently selected execbel
# Original:  Interactive console for manipulating currently selected accessible
# ------------------------------
# 20
# Hindi: घटना मानिटर
# Translated:  Event Monitor
# Original:  Event monitor
# ------------------------------
# 21
# Hindi: घटनाओं को मानिटर करें (_ M)
# Translated:  _ Monitor Events
# Original:  _ Monitor Events
# ------------------------------
# 22
# Hindi: चुनाव को हटाएं (C _)
# Translated:  _ Remove Selection
# Original:  C _ lear Selection
# ------------------------------
# 23
# Hindi: सभी
# Translated:  All
# Original:  Everything
# ------------------------------
# 24
# Hindi: चुने गए अनुप्रयोग
# Translated:  Selected applications
# Original:  Selected application
# ------------------------------
# 25
# Hindi: चुने गए एक्सेसेबेल
# Translated:  Selected Exceptions
# Original:  Selected accessible
# ------------------------------
# 26
# Hindi: स्रोत
# Translated:  source
# Original:  Source
# ------------------------------
# 27
# Hindi: घटना मानिटर
# Translated:  Event Monitor
# Original:  Event Monitor
# ------------------------------
# 28
# Hindi: चुने गए प्रकारों और स्रोतों से घटनाएं जैसे-जैसे घटित होती हैं, उन्हें दर्शाता है
# Translated:  Displays events as they occur from the selected types and sources.
# Original:  Shows events as they occur from selected types and sources
# ------------------------------
# 29
# Hindi: अंतिम प्रविष्ट घटना को हाइलाइट करो
# Translated:  Highlight last entered event
# Original:  Highlight last event entry
# ------------------------------
# 30
# Hindi: घटना रेकोर्डिंग शुरू करो/रोको
# Translated:  Start / Stop Event Recording
# Original:  Start / stop event recording
# ------------------------------
# 31
# Hindi: घटना रोजनामचा मिटाओ
# Translated:  Delete Event Daily Name
# Original:  Clear event log
# ------------------------------
# 32
# Hindi: कोई विवरण नहीं
# Translated:  No Details
# Original:  (no description)
# ------------------------------
# 33
# Hindi: वर्णन
# Translated:  description
# Original:  Description
# ------------------------------
# 34
# Hindi: दिखाएं
# Translated:  Show
# Original:  Show
# ------------------------------
# 35
# Hindi: पहुंचनीय
# Translated:  accessible
# Original:  _ Accessible
# ------------------------------
# 36
# Hindi: कार्रवाई संपन्न करें
# Translated:  Perform Action
# Original:  Perform action
# ------------------------------
# 37
# Hindi: कार्रवाई (_ o)
# Translated:  _ Action
# Original:  Acti _ on
# ------------------------------
# 38
# Hindi: आईडी
# Translated:  ID
# Original:  ID
# ------------------------------
# 39
# Hindi: औजार बक्सा
# Translated:  Toolbox
# Original:  Toolkit
# ------------------------------
# 40
# Hindi: संस्करण
# Translated:  version
# Original:  Version
# ------------------------------
# 41
# Hindi: अनुप्रयोग
# Translated:  application
# Original:  Ap _ plication
# ------------------------------
# 42
# Hindi: संग्रह
# Translated:  collection
# Original:  Col _ lection
# ------------------------------
# 43
# Hindi: 0, 0
# Translated:  0, 0
# Original:  0, 0
# ------------------------------
# 44
# Hindi: सापेक्ष स्थिति
# Translated:  relative position
# Original:  Relative position
# ------------------------------
# 45
# Hindi: आकार
# Translated:  size
# Original:  Size
# ------------------------------
# 46
# Hindi: विडजेट
# Translated:  Widget
# Original:  WIDGET
# ------------------------------
# 47
# Hindi: स्तर
# Translated:  level
# Original:  Layer
# ------------------------------
# 48
# Hindi: एमडीआई-जेड-क्रम
# Translated:  MDI - JD series
# Original:  MDI - Z - order
# ------------------------------
# 49
# Hindi: अल्फा
# Translated:  alpha
# Original:  Alpha
# ------------------------------
# 50
# Hindi: निरपेक्ष स्थिति
# Translated:  Absolute state
# Original:  Absolute position
# ------------------------------
# 51
# Hindi: घटक
# Translated:  component
# Original:  Co _ mponent
# ------------------------------
# 52
# Hindi: डेस्कटोप
# Translated:  Desktop
# Original:  Des _ ktop
# ------------------------------
# 53
# Hindi: स्थान-विशिष्टः
# Translated:  Location specification:
# Original:  Locale:
# ------------------------------
# 54
# Hindi: प्रलेख
# Translated:  document
# Original:  _ Document
# ------------------------------
# 55
# Hindi: हाइपरकड़ी
# Translated:  hippopotamus
# Original:  Hyperlink
# ------------------------------
# 56
# Hindi: हाइपरपाठ
# Translated:  Hypertext
# Original:  H _ ypertext
# ------------------------------
# 57
# Hindi: स्थिति
# Translated:  position
# Original:  Position
# ------------------------------
# 58
# Hindi: वर्णन
# Translated:  description
# Original:  Description
# ------------------------------
# 59
# Hindi: स्थान-विशिष्ट
# Translated:  space debris
# Original:  Locale
# ------------------------------
# 60
# Hindi: छवि (_ I)
# Translated:  _ Image
# Original:  _ Image
# ------------------------------
# 61
# Hindi: प्रवेश सहायक
# Translated:  entrance assistant
# Original:  Lo _ gin Helper
# ------------------------------
# 62
# Hindi: सभी चुनें
# Translated:  Select All
# Original:  Select All
# ------------------------------
# 63
# Hindi: चयन (_ S)
# Translated:  _ Selection
# Original:  _ Selection
# ------------------------------
# 64
# Hindi: प्रवाहित करनेयोग्य विषयवस्तु
# Translated:  Floating theme
# Original:  St _ reamable Content
# ------------------------------
# 65
# Hindi: चुने गए स्तंभ
# Translated:  Selected columns
# Original:  Selected columns
# ------------------------------
# 66
# Hindi: चुनी गई पंक्तियां
# Translated:  Selected lines
# Original:  Selected rows
# ------------------------------
# 67
# Hindi: स्तंभ
# Translated:  column
# Original:  Columns
# ------------------------------
# 68
# Hindi: पंक्तियां
# Translated:  rows
# Original:  Rows
# ------------------------------
# 69
# Hindi: & lt; bgt; सारणी सूचनाlt;/bgt;
# Translated:  & lt; bgt; Table Informationlt; /bgt;
# Original:  Table Information
# ------------------------------
# 70
# Hindi: नाम (x, y)
# Translated:  Name (x, y)
# Original:  name (x, y)
# ------------------------------
# 71
# Hindi: शीर्षकः
# Translated:  Title:
# Original:  Header:
# ------------------------------
# 72
# Hindi: विस्तारः
# Translated:  Extension:
# Original:  Extents:
# ------------------------------
# 73
# Hindi: पंक्ति
# Translated:  row
# Original:  Row
# ------------------------------
# 74
# Hindi: स्तंभ
# Translated:  column
# Original:  Column
# ------------------------------
# 75
# Hindi: & lt; bgt; चुनी गई कोशिकाlt;/bgt;
# Translated:  & lt; bgt; selected celllt; /bgt;
# Original:  Selected Cell
# ------------------------------
# 76
# Hindi: सारणी (_ T)
# Translated:  _ Table
# Original:  _ Table
# ------------------------------
# 77
# Hindi: ओफसेट
# Translated:  Offset
# Original:  Offset
# ------------------------------
# 78
# Hindi: डिफोल्टों को शामिल करें
# Translated:  Include defaults
# Original:  Include defaults
# ------------------------------
# 79
# Hindi: पाठ (_ x)
# Translated:  _ Text
# Original:  Te _ xt
# ------------------------------
# 80
# Hindi: मौजूदा मान
# Translated:  Current value
# Original:  Current value
# ------------------------------
# 81
# Hindi: न्यूनतम वृद्धि
# Translated:  minimum growth
# Original:  Minimum increment
# ------------------------------
# 82
# Hindi: अधिकतम मान
# Translated:  Maximum value
# Original:  Maximum value
# ------------------------------
# 83
# Hindi: न्यूनतम मान
# Translated:  Minimum value
# Original:  Minimum value
# ------------------------------
# 84
# Hindi: मान
# Translated:  value
# Original:  Val _ ue
# ------------------------------
# 85
# Hindi: अंतराफलक दर्शक
# Translated:  Interface Viewer
# Original:  Interface Viewer
# ------------------------------
# 86
# Hindi: अंतराफलक के विभिन्न गुणों को देखने देता है
# Translated:  Shows the various properties of the interface
# Original:  Allows viewing of various interface properties
# ------------------------------
# 87
# Hindi: (क्रियान्वित नहीं हुआ है)
# Translated:  (Not implemented)
# Original:  (not implemented)
# ------------------------------
# 88
# Hindi: नाम
# Translated:  name
# Original:  Name
# ------------------------------
# 89
# Hindi: यूआरआई
# Translated:  URI
# Original:  URI
# ------------------------------
# 90
# Hindi: प्रारंभ
# Translated:  start
# Original:  Start
# ------------------------------
# 91
# Hindi: अंत
# Translated:  end
# Original:  End
# ------------------------------
# 92
# Hindi: बहुत अधिक चयनीय शिशु हैं
# Translated:  Too many selectable babies
# Original:  Too many selectable children
# ------------------------------
# 93
# Hindi: तेज चुनाव
# Translated:  fast election
# Original:  Quick Select
# ------------------------------
# 94
# Hindi: प्लग-इन जिसमें हैं एक्सेसेबेलों को तेजी से चुनने के लिए कई विधियां
# Translated:  A plugin that contains several methods to quickly select execbels
# Original:  Plugin with various methods of selecting accessibles quickly.
# ------------------------------
# 95
# Hindi: अंतिम बार फोकस किए गए एक्सेसेबल को जांचें
# Translated:  Check last focused accessibility
# Original:  Inspect last focused accessible
# ------------------------------
# 96
# Hindi: माउस के अधीन जो एक्सेसेबल है, उसे जांचें
# Translated:  Check which is accessible under the mouse
# Original:  Inspect accessible under mouse
# ------------------------------
# 97
# Hindi: वतनी
# Translated:  mantle
# Original:  Native
# ------------------------------
# 98
# Hindi: श्वानपुच्छ
# Translated:  squirrel
# Original:  Dogtail
# ------------------------------
# 99
# Hindi: एलडीटीपी
# Translated:  LDTP
# Original:  LDTP
# ------------------------------
# 100
# Hindi: लिपि प्रकार
# Translated:  Type
# Original:  Script Type
# ------------------------------
# 101
# Hindi: लिपि रेकोर्डर
# Translated:  script recorder
# Original:  Script Recorder
# ------------------------------
# 102
# Hindi: श्वानपुच्छ शैली की लिपियां निर्मित करता है
# Translated:  Swanpuchch forms scripts in style
# Original:  Creates dogtail style scripts
# ------------------------------
# 103
# Hindi: वर्तमान लिपि (स्क्रिप्ट) खो जाएगी।
# Translated:  The current script will be lost.
# Original:  The current script will be lost.
# ------------------------------
# 104
# Hindi: मिटाने की पुष्टि करें
# Translated:  Confirm Delete
# Original:  Confirm clear
# ------------------------------
# 105
# Hindi: स्कीमाः
# Translated:  Schema:
# Original:  Sche _ ma:
# ------------------------------
# 106
# Hindi: सत्यापन
# Translated:  authentication
# Original:  V _ alidate
# ------------------------------
# 107
# Hindi: खाली
# Translated:  empty
# Original:  Idle
# ------------------------------
# 108
# Hindi: कोई विवरण नहीं
# Translated:  No Details
# Original:  No description
# ------------------------------
# 109
# Hindi: एटी-एसपीआई सत्यापक
# Translated:  AT - SPI Verifier
# Original:  AT - SPI Validator
# ------------------------------
# 110
# Hindi: अनुप्रयोग की पहुंचनीयता का सत्यापन करता है
# Translated:  Verifies the accessibility of the application
# Original:  Validates application accessibility
# ------------------------------
# 111
# Hindi: स्तर
# Translated:  level
# Original:  Level
# ------------------------------
# 112
# Hindi: भूमिका
# Translated:  role
# Original:  Role
# ------------------------------
# 113
# Hindi: सहेज रहे हैं
# Translated:  Saving
# Original:  Saving
# ------------------------------
# 114
# Hindi: पुष्टि कर रहे हैं
# Translated:  Confirming
# Original:  Validating
# ------------------------------
# 115
# Hindi: अपवाद
# Translated:  exception
# Original:  EXCEPT
# ------------------------------
# 116
# Hindi: त्रुटि
# Translated:  error
# Original:  ERROR
# ------------------------------
# 117
# Hindi: चेतावनी
# Translated:  warning
# Original:  WARN
# ------------------------------
# 118
# Hindi: सूचना
# Translated:  Information
# Original:  INFO
# ------------------------------
# 119
# Hindi: दोषमुक्त करें
# Translated:  Debug
# Original:  DEBUG
# ------------------------------
# 120
# Hindi: मूल
# Translated:  root
# Original:  Basic
# ------------------------------
# 121
# Hindi: मूलभूत जीयूआई अनुप्रयोग पहुंचनीयता का परीक्षण करता है
# Translated:  Tests the accessibility of the default GUI application
# Original:  Tests fundamental GUI application accessibility
# ------------------------------
# 122
# Hindi: % s जिस पर कार्रवाई हो सकती है, वह न तो फोकस करने योग्य है न ही चयनीय
# Translated:  % s on which action can be taken is neither focusable nor selective
# Original:  actionable% s is not focusable or selectable
# ------------------------------
# 123
# Hindi: अंतर्क्रियात्मक% s कार्रवाई करने योग्य नहीं है
# Translated:  Interactive% s is not actionable
# Original:  interactive% s is not actionable
# ------------------------------
# 124
# Hindi: एक से अधिक विडजेट फोकस में है
# Translated:  More than one widget is in focus
# Original:  more than one focused widget
# ------------------------------
# 125
# Hindi: % s का कोई पाठ अंतराफलक नहीं है
# Translated:  % s has no text interface
# Original:  % s has no text interface
# ------------------------------
# 126
# Hindi: अभिभावक में% s सूची शिशु सूची सेमेल नहीं खाती
# Translated:  The% s list in parent does not match the child list
# Original:  % s index in parent does not match child index
# ------------------------------
# 127
# Hindi: % s संबंध के लिए अन्योन्य गायब है
# Translated:  Other for% s relation missing
# Original:  Missing reciprocal for% s relation
# ------------------------------
# 128
# Hindi: % s गायब नाम या सूचक
# Translated:  % s missing name or indicator
# Original:  % s missing name or label
# ------------------------------
# 129
# Hindi: फोकस योग्य% s में सारणी अंतराफलक है, कोई चयनीय अंतराफलक नहीं हैbutton has focused state without focusable state
# Translated:  The focusable% s has a table interface, no selectable interface
# Original:  focusable% s has table interface, no selection interface
# ------------------------------
# 130
# Hindi: % s में% s स्थिति है, पर उसके साथ% s स्थिति नहीं है
# Translated:  % s has% s status, but does not have% s status with it
# Original:  % s has% s state without% s state
# ------------------------------
# 131
# Hindi: % s किसी समुच्चय का सदस्य नहीं है
# Translated:  % s is not a member of any set
# Original:  % s does not belong to a set
# ------------------------------
# 132
# Hindi: % (rolename) s सूची% (num) d पंक्ति और स्तंभ से मेल नहीं खातेparent indexrow and column index
# Translated:  % (rolename) s list% (num) d does not match row and column index
# Original:  % (rolename) s index% (num) d does not match row and column
# ------------------------------
# 133
# Hindi: % (rolename) s अभिभावक सूची% (num1) d पंक्ति और स्तंभ सूची% (num2) d से मेल नहीं खाते
# Translated:  % (rolename) s Parent list% (num1) d does not match line and column list% (num2) d
# Original:  % (rolename) s parent index% (num1) d does not match row and column index% (num2) d
# ------------------------------
# 134
# Hindi: % s का कोई नाम या विवरण नहीं
# Translated:  No name or description of% s
# Original:  % s has no name or description
# ------------------------------
# 135
# Hindi: पसंद (_ P)...
# Translated:  _ Bookmarks...
# Original:  _ Preferences...
# ------------------------------
# 136
# Hindi: विषय सूची (_ C)
# Translated:  _ Subject List
# Original:  _ Contents
# ------------------------------
# 137
# Hindi: एक्सेरसाइसर आपके डेस्कटोप में मौजूद अनुप्रयोग नहीं देख पाया। इस समस्या के समाधान के लिए आपको डेस्कटोप पहुंचनीयता को सक्रिय करना होगा। क्या आप इसे सक्रिय करना चाहते हैं?
# Translated:  Thexersizer could not find an application on your desktop. To solve this problem you must enable desktop accessibility. Do you want to enable it?
# Original:  Accerciser could not see the applications on your desktop. You must enable desktop accessibility to fix this problem. Do you want to enable it now?
# ------------------------------
# 138
# Hindi: टिप्पणीः परिवर्तन सत्रांत (लोगआउट) के बाद ही प्रभाव में आएंगे।
# Translated:  Note: Changes will only take effect after logout.
# Original:  Note: Changes only take effect after logout.
# ------------------------------
# 139
# Hindi: शिशु
# Translated:  child
# Original:  Children
# ------------------------------
# 140
# Hindi: पंजी ताजा करें (_ R)
# Translated:  _ Refresh Register
# Original:  _ Refresh Registry
# ------------------------------
# 141
# Hindi: सभी को ताजा करें
# Translated:  Refresh All
# Original:  Refresh all
# ------------------------------
# 142
# Hindi: आसंधि (नोड) को ताजा करें (_ N)
# Translated:  _ Refresh Protocols
# Original:  Refresh _ Node
# ------------------------------
# 143
# Hindi: चुनी गई आसंधियों (नोड) के शिशुओं को ताजा करें
# Translated:  Refresh the children of the selected nodes
# Original:  Refresh selected node 's children
# ------------------------------
# 144
# Hindi: घटक
# Translated:  component
# Original:  Component
# ------------------------------
# 145
# Hindi: कार्य
# Translated:  work
# Original:  Task
# ------------------------------
# 146
# Hindi: कुंजी
# Translated:  key
# Original:  Key
# ------------------------------
# 147
# Hindi: आल्ट
# Translated:  altar
# Original:  Alt
# ------------------------------
# 148
# Hindi: कंट्रोल
# Translated:  Control
# Original:  Ctrl
# ------------------------------
# 149
# Hindi: शिफ्ट
# Translated:  Shift
# Original:  Shift
# ------------------------------
# 150
# Hindi: ऊपरी पटल
# Translated:  top panel
# Original:  Top panel
# ------------------------------
# 151
# Hindi: निचला पटल
# Translated:  Lower Panel
# Original:  Bottom panel
# ------------------------------
# 152
# Hindi: एक्सेर्साइसर पसंद
# Translated:  Cursor Preferences
# Original:  accerciser Preferences
# ------------------------------
# 153
# Hindi: प्लगइन्स
# Translated:  Plugins
# Original:  Plugins
# ------------------------------
# 154
# Hindi: सार्वत्रिक फटाफट कुंजियां
# Translated:  Global FAT keys
# Original:  Global Hotkeys
# ------------------------------
# 155
# Hindi: हाइलाइटन
# Translated:  highlight
# Original:  Highlighting
# ------------------------------
# 156
# Hindi: हाइलाइट अवधिः
# Translated:  Highlight period:
# Original:  Highlight duration:
# ------------------------------
# 157
# Hindi: सीमांत रंगः
# Translated:  Border color:
# Original:  Border color:
# ------------------------------
# 158
# Hindi: हाइलाइट बक्से का सीमांत रंग
# Translated:  Limit color of the highlight box
# Original:  The border color of the highlight box
# ------------------------------
# 159
# Hindi: भराई का रंगः
# Translated:  Fill color:
# Original:  Fill color:
# ------------------------------
# 160
# Hindi: हाइलाइट बक्से का भराई रंग
# Translated:  Fill color of the highlight box
# Original:  The fill color of the highlight box
# ------------------------------
# 161
# Hindi: रविशंकर श्रीवास्तव (raviratlami @yahoo. com) राजेश रंजन (rajeshkajha @yahoo. com) ल. बालसुब्रमण्यम (l. balasubramaniam @gmail. com)
# Translated:  Rajeshkajha @ yahoo. com L. balasubramaniam @ gmail. com
# Original:  translator - credits
# ------------------------------
# 162
# Hindi: एक अंतर्क्रियात्मक पाइथन पहुंचनीयता अन्वेषक
# Translated:  An interactive Python accessibility explorer
# Original:  An interactive Python accessibility explorer
# ------------------------------
# 163
# Hindi: एक्सेर्साइसर सर्वाधिकार © 2006,2007 आईबीएम निगम (बीएसडी)
# Translated:  Copyright © 2006, 2007 IBM Corporation (BSD)
# Original:  accerciser Copyright © 2006, 2007 IBM Corporation (BSD)
# ------------------------------
# 164
# Hindi: नया बीएसडी लाइसेन्स विवरण के लिए देखिए प्रतिलिपीकरण और सूचना फाइलें
# Translated:  See copying and information files for new BSD license details
# Original:  The New BSD License See the COPYING and NOTICE files for details.
# ------------------------------
# 165
# Hindi: जाल स्थल
# Translated:  web site
# Original:  Web site
# ------------------------------
# 166
# Hindi: पसंद जोड़ें... (_ A)
# Translated:  _ Add Bookmarks...
# Original:  _ Add Bookmark...
# ------------------------------
# 167
# Hindi: चुने गए एक्सेसेबलों को पुस्तक-चिह्नित करें
# Translated:  Bookmark Selected Accessibility
# Original:  Bookmark selected accessible.
# ------------------------------
# 168
# Hindi: पुस्तक चिह्न संपादित करें (_ E)...
# Translated:  _ Edit Book Mark...
# Original:  _ Edit Bookmarks...
# ------------------------------
# 169
# Hindi: पुस्तक-चिह्नों को प्रबंधित करें।
# Translated:  Manage bookmarks.
# Original:  Manage bookmarks.
# ------------------------------
# 170
# Hindi: पुस्तक चिह्नों को संपादित करें...
# Translated:  Edit Book Marks...
# Original:  Edit Bookmarks...
# ------------------------------
# 171
# Hindi: शीर्षक
# Translated:  title
# Original:  Title
# ------------------------------
# 172
# Hindi: अनुप्रयोग
# Translated:  application
# Original:  Application
# ------------------------------
# 173
# Hindi: पथ
# Translated:  path
# Original:  Path
# ------------------------------
# 174
# Hindi: पुस्तक-चिह्न जोड़ें...
# Translated:  Add Bookmark...
# Original:  Add Bookmark...
# ------------------------------
# 175
# Hindi: शीर्षकः
# Translated:  Title:
# Original:  Title:
# ------------------------------
# 176
# Hindi: अनुप्रयोगः
# Translated:  Application:
# Original:  Application:
# ------------------------------
# 177
# Hindi: पथः
# Translated:  Path:
# Original:  Path:
# ------------------------------
# 178
# Hindi: प्लग-इन त्रुटियां
# Translated:  Plugin Errors
# Original:  Plugin Errors
# ------------------------------
# 179
# Hindi: दृश्य
# Translated:  view
# Original:  View
# ------------------------------
# 180
# Hindi: कोई दृश्य नहीं है
# Translated:  No View
# Original:  No view
# ------------------------------
# 181
# Hindi: एकल प्लग-इन दृश्य
# Translated:  Single Plugin View
# Original:  _ Single plugins view
# ------------------------------
# 182
# Hindi: प्लग-इन दृश्य
# Translated:  Plugin View
# Original:  Plugin View
# ------------------------------
# 183
# Hindi: प्लग-इन दृश्य (% d)
# Translated:  Plugin View (% d)
# Original:  Plugin View (% d)
# ------------------------------
# 184
# Hindi: नया दृश्य...
# Translated:  New View...
# Original:  _ New view...
# ------------------------------
# 185
# Hindi: नया दृश्य...
# Translated:  New View...
# Original:  New View...
# ------------------------------
# 186
# Hindi: फाइल (F)
# Translated:  & Files
# Original:  _ File
# ------------------------------
# 187
# Hindi: संपादित करें
# Translated:  Edit
# Original:  _ Edit
# ------------------------------
# 188
# Hindi: पुस्तक-चिह्न संपादित करें (_ E)...
# Translated:  _ Edit Bookmarks...
# Original:  _ Bookmarks
# ------------------------------
# 189
# Hindi: दृश्य _ (V)
# Translated:  _ View
# Original:  _ View
# ------------------------------
# 190
# Hindi: मदद
# Translated:  help
# Original:  _ Help
# ------------------------------
# 191
# Hindi: पूरा नाम
# Translated:  Full Name
# Original:  Full name
# ------------------------------
# 192
# Hindi: कुंजी बंधन
# Translated:  Key binding
# Original:  Key binding
# ------------------------------
# 193
# Hindi: विषय प्रकार
# Translated:  Subject Type
# Original:  Content type
# ------------------------------
# 194
# Hindi: अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# Translated:  Benefit your application from accessibility exercises
# Original:  Give your application an accessibility workout
# ------------------------------
# 195
# Hindi: एक्सेर्साइसर पहुंचनीयता अन्वेषक
# Translated:  Cursor Accessibility Explorer
# Original:  Accerciser Accessibility Explorer
# ------------------------------
# 196
# Hindi: निचले पटल के लिए डिफोल्ट प्लग-इन खाका
# Translated:  Default plug - in for bottom panel
# Original:  The default plugin layout for the bottom panel
# ------------------------------
# 197
# Hindi: ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका
# Translated:  Default plug - in for top panel
# Original:  The default plugin layout for the top panel
# ------------------------------
# 198
# Hindi: उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# Translated:  List of plugins that have been disabled by default
# Original:  A list of plugins that are disabled by default
# ------------------------------
# 199
# Hindi: अवधि को हाइलाइट रकें
# Translated:  Highlight period
# Original:  Highlight duration
# ------------------------------
# 200
# Hindi: पहुंचनीय आसंधि (नोड) को चुनते समय हाइलाइट बक्से की अवधि
# Translated:  Duration of the highlight box when selecting the accessible node
# Original:  The duration of the highlight box when selecting accessible nodes
# ------------------------------
# 201
# Hindi: सीमांत (बोर्डर) के रंग को हाइलाइट करें
# Translated:  Highlight border (boarder) color
# Original:  Highlight border color
# ------------------------------
# 202
# Hindi: हाइलाइट किए गए सीमांत का रंग और अपारदर्शिता।
# Translated:  The color and opacity of the highlighted border.
# Original:  The color and opacity of the highlight border.
# ------------------------------
# 203
# Hindi: भराई के रंग को हाइलाइट करें
# Translated:  Highlight fill color
# Original:  Highlight fill color
# ------------------------------
# 204
# Hindi: हाइलाइट किया गया भराई का रंग और पारदर्शिता।
# Translated:  The color and transparency of the highlighted filling.
# Original:  The color and opacity of the highlight fill.
# ------------------------------
# 205
# Hindi: एपीआई विचरक
# Translated:  API Switcher
# Original:  API Browser
# ------------------------------
# 206
# Hindi: इस समय जिसे प्राप्त किया गया हो, उसकी विभिन्न विधियों (मेथड) में विचरण करें
# Translated:  Navigate to the different methods (methods) of the time which has been received.
# Original:  Browse the various methods of the current accessible
# ------------------------------
# 207
# Hindi: निजी गुणों को छिपाएं
# Translated:  Hide private properties
# Original:  Hide private attributes
# ------------------------------
# 208
# Hindi: विधि
# Translated:  method
# Original:  Method
# ------------------------------
# 209
# Hindi: गुणधर्म
# Translated:  property
# Original:  Property
# ------------------------------
# 210
# Hindi: मान
# Translated:  value
# Original:  Value
# ------------------------------
# 211
# Hindi: आईपाइथन कन्सोल
# Translated:  iPython console
# Original:  IPython Console
# ------------------------------
# 212
# Hindi: इस समय चुने गए एक्सेसेबेल से काम लेने के लिए अंतर्क्रियात्मक कन्सोल
# Translated:  Interactive console to work with the currently selected execbel
# Original:  Interactive console for manipulating currently selected accessible
# ------------------------------
# 213
# Hindi: घटना मानिटर
# Translated:  Event Monitor
# Original:  Event monitor
# ------------------------------
# 214
# Hindi: घटनाओं को मानिटर करें (_ M)
# Translated:  _ Monitor Events
# Original:  _ Monitor Events
# ------------------------------
# 215
# Hindi: चुनाव को हटाएं (C _)
# Translated:  _ Remove Selection
# Original:  C _ lear Selection
# ------------------------------
# 216
# Hindi: सभी
# Translated:  All
# Original:  Everything
# ------------------------------
# 217
# Hindi: चुने गए अनुप्रयोग
# Translated:  Selected applications
# Original:  Selected application
# ------------------------------
# 218
# Hindi: चुने गए एक्सेसेबेल
# Translated:  Selected Exceptions
# Original:  Selected accessible
# ------------------------------
# 219
# Hindi: स्रोत
# Translated:  source
# Original:  Source
# ------------------------------
# 220
# Hindi: घटना मानिटर
# Translated:  Event Monitor
# Original:  Event Monitor
# ------------------------------
# 221
# Hindi: चुने गए प्रकारों और स्रोतों से घटनाएं जैसे-जैसे घटित होती हैं, उन्हें दर्शाता है
# Translated:  Displays events as they occur from the selected types and sources.
# Original:  Shows events as they occur from selected types and sources
# ------------------------------
# 222
# Hindi: अंतिम प्रविष्ट घटना को हाइलाइट करो
# Translated:  Highlight last entered event
# Original:  Highlight last event entry
# ------------------------------
# 223
# Hindi: घटना रेकोर्डिंग शुरू करो/रोको
# Translated:  Start / Stop Event Recording
# Original:  Start / stop event recording
# ------------------------------
# 224
# Hindi: घटना रोजनामचा मिटाओ
# Translated:  Delete Event Daily Name
# Original:  Clear event log
# ------------------------------
# 225
# Hindi: कोई विवरण नहीं
# Translated:  No Details
# Original:  (no description)
# ------------------------------
# 226
# Hindi: वर्णन
# Translated:  description
# Original:  Description
# ------------------------------
# 227
# Hindi: दिखाएं
# Translated:  Show
# Original:  Show
# ------------------------------
# 228
# Hindi: पहुंचनीय
# Translated:  accessible
# Original:  _ Accessible
# ------------------------------
# 229
# Hindi: कार्रवाई संपन्न करें
# Translated:  Perform Action
# Original:  Perform action
# ------------------------------
# 230
# Hindi: कार्रवाई (_ o)
# Translated:  _ Action
# Original:  Acti _ on
# ------------------------------
# 231
# Hindi: आईडी
# Translated:  ID
# Original:  ID
# ------------------------------
# 232
# Hindi: औजार बक्सा
# Translated:  Toolbox
# Original:  Toolkit
# ------------------------------
# 233
# Hindi: संस्करण
# Translated:  version
# Original:  Version
# ------------------------------
# 234
# Hindi: अनुप्रयोग
# Translated:  application
# Original:  Ap _ plication
# ------------------------------
# 235
# Hindi: संग्रह
# Translated:  collection
# Original:  Col _ lection
# ------------------------------
# 236
# Hindi: 0, 0
# Translated:  0, 0
# Original:  0, 0
# ------------------------------
# 237
# Hindi: सापेक्ष स्थिति
# Translated:  relative position
# Original:  Relative position
# ------------------------------
# 238
# Hindi: आकार
# Translated:  size
# Original:  Size
# ------------------------------
# 239
# Hindi: विडजेट
# Translated:  Widget
# Original:  WIDGET
# ------------------------------
# 240
# Hindi: स्तर
# Translated:  level
# Original:  Layer
# ------------------------------
# 241
# Hindi: एमडीआई-जेड-क्रम
# Translated:  MDI - JD series
# Original:  MDI - Z - order
# ------------------------------
# 242
# Hindi: अल्फा
# Translated:  alpha
# Original:  Alpha
# ------------------------------
# 243
# Hindi: निरपेक्ष स्थिति
# Translated:  Absolute state
# Original:  Absolute position
# ------------------------------
# 244
# Hindi: घटक
# Translated:  component
# Original:  Co _ mponent
# ------------------------------
# 245
# Hindi: डेस्कटोप
# Translated:  Desktop
# Original:  Des _ ktop
# ------------------------------
# 246
# Hindi: स्थान-विशिष्टः
# Translated:  Location specification:
# Original:  Locale:
# ------------------------------
# 247
# Hindi: प्रलेख
# Translated:  document
# Original:  _ Document
# ------------------------------
# 248
# Hindi: हाइपरकड़ी
# Translated:  hippopotamus
# Original:  Hyperlink
# ------------------------------
# 249
# Hindi: हाइपरपाठ
# Translated:  Hypertext
# Original:  H _ ypertext
# ------------------------------
# 250
# Hindi: स्थिति
# Translated:  position
# Original:  Position
# ------------------------------
# 251
# Hindi: वर्णन
# Translated:  description
# Original:  Description
# ------------------------------
# 252
# Hindi: स्थान-विशिष्ट
# Translated:  space debris
# Original:  Locale
# ------------------------------
# 253
# Hindi: छवि (_ I)
# Translated:  _ Image
# Original:  _ Image
# ------------------------------
# 254
# Hindi: प्रवेश सहायक
# Translated:  entrance assistant
# Original:  Lo _ gin Helper
# ------------------------------
# 255
# Hindi: सभी चुनें
# Translated:  Select All
# Original:  Select All
# ------------------------------
# 256
# Hindi: चयन (_ S)
# Translated:  _ Selection
# Original:  _ Selection
# ------------------------------
# 257
# Hindi: प्रवाहित करनेयोग्य विषयवस्तु
# Translated:  Floating theme
# Original:  St _ reamable Content
# ------------------------------
# 258
# Hindi: चुने गए स्तंभ
# Translated:  Selected columns
# Original:  Selected columns
# ------------------------------
# 259
# Hindi: चुनी गई पंक्तियां
# Translated:  Selected lines
# Original:  Selected rows
# ------------------------------
# 260
# Hindi: स्तंभ
# Translated:  column
# Original:  Columns
# ------------------------------
# 261
# Hindi: पंक्तियां
# Translated:  rows
# Original:  Rows
# ------------------------------
# 262
# Hindi: & lt; bgt; सारणी सूचनाlt;/bgt;
# Translated:  & lt; bgt; Table Informationlt; /bgt;
# Original:  Table Information
# ------------------------------
# 263
# Hindi: नाम (x, y)
# Translated:  Name (x, y)
# Original:  name (x, y)
# ------------------------------
# 264
# Hindi: शीर्षकः
# Translated:  Title:
# Original:  Header:
# ------------------------------
# 265
# Hindi: विस्तारः
# Translated:  Extension:
# Original:  Extents:
# ------------------------------
# 266
# Hindi: पंक्ति
# Translated:  row
# Original:  Row
# ------------------------------
# 267
# Hindi: स्तंभ
# Translated:  column
# Original:  Column
# ------------------------------
# 268
# Hindi: & lt; bgt; चुनी गई कोशिकाlt;/bgt;
# Translated:  & lt; bgt; selected celllt; /bgt;
# Original:  Selected Cell
# ------------------------------
# 269
# Hindi: सारणी (_ T)
# Translated:  _ Table
# Original:  _ Table
# ------------------------------
# 270
# Hindi: ओफसेट
# Translated:  Offset
# Original:  Offset
# ------------------------------
# 271
# Hindi: डिफोल्टों को शामिल करें
# Translated:  Include defaults
# Original:  Include defaults
# ------------------------------
# 272
# Hindi: पाठ (_ x)
# Translated:  _ Text
# Original:  Te _ xt
# ------------------------------
# 273
# Hindi: मौजूदा मान
# Translated:  Current value
# Original:  Current value
# ------------------------------
# 274
# Hindi: न्यूनतम वृद्धि
# Translated:  minimum growth
# Original:  Minimum increment
# ------------------------------
# 275
# Hindi: अधिकतम मान
# Translated:  Maximum value
# Original:  Maximum value
# ------------------------------
# 276
# Hindi: न्यूनतम मान
# Translated:  Minimum value
# Original:  Minimum value
# ------------------------------
# 277
# Hindi: मान
# Translated:  value
# Original:  Val _ ue
# ------------------------------
# 278
# Hindi: अंतराफलक दर्शक
# Translated:  Interface Viewer
# Original:  Interface Viewer
# ------------------------------
# 279
# Hindi: अंतराफलक के विभिन्न गुणों को देखने देता है
# Translated:  Shows the various properties of the interface
# Original:  Allows viewing of various interface properties
# ------------------------------
# 280
# Hindi: (क्रियान्वित नहीं हुआ है)
# Translated:  (Not implemented)
# Original:  (not implemented)
# ------------------------------
# 281
# Hindi: नाम
# Translated:  name
# Original:  Name
# ------------------------------
# 282
# Hindi: यूआरआई
# Translated:  URI
# Original:  URI
# ------------------------------
# 283
# Hindi: प्रारंभ
# Translated:  start
# Original:  Start
# ------------------------------
# 284
# Hindi: अंत
# Translated:  end
# Original:  End
# ------------------------------
# 285
# Hindi: बहुत अधिक चयनीय शिशु हैं
# Translated:  Too many selectable babies
# Original:  Too many selectable children
# ------------------------------
# 286
# Hindi: तेज चुनाव
# Translated:  fast election
# Original:  Quick Select
# ------------------------------
# 287
# Hindi: प्लग-इन जिसमें हैं एक्सेसेबेलों को तेजी से चुनने के लिए कई विधियां
# Translated:  A plugin that contains several methods to quickly select execbels
# Original:  Plugin with various methods of selecting accessibles quickly.
# ------------------------------
# 288
# Hindi: अंतिम बार फोकस किए गए एक्सेसेबल को जांचें
# Translated:  Check last focused accessibility
# Original:  Inspect last focused accessible
# ------------------------------
# 289
# Hindi: माउस के अधीन जो एक्सेसेबल है, उसे जांचें
# Translated:  Check which is accessible under the mouse
# Original:  Inspect accessible under mouse
# ------------------------------
# 290
# Hindi: वतनी
# Translated:  mantle
# Original:  Native
# ------------------------------
# 291
# Hindi: श्वानपुच्छ
# Translated:  squirrel
# Original:  Dogtail
# ------------------------------
# 292
# Hindi: एलडीटीपी
# Translated:  LDTP
# Original:  LDTP
# ------------------------------
# 293
# Hindi: लिपि प्रकार
# Translated:  Type
# Original:  Script Type
# ------------------------------
# 294
# Hindi: लिपि रेकोर्डर
# Translated:  script recorder
# Original:  Script Recorder
# ------------------------------
# 295
# Hindi: श्वानपुच्छ शैली की लिपियां निर्मित करता है
# Translated:  Swanpuchch forms scripts in style
# Original:  Creates dogtail style scripts
# ------------------------------
# 296
# Hindi: वर्तमान लिपि (स्क्रिप्ट) खो जाएगी।
# Translated:  The current script will be lost.
# Original:  The current script will be lost.
# ------------------------------
# 297
# Hindi: मिटाने की पुष्टि करें
# Translated:  Confirm Delete
# Original:  Confirm clear
# ------------------------------
# 298
# Hindi: स्कीमाः
# Translated:  Schema:
# Original:  Sche _ ma:
# ------------------------------
# 299
# Hindi: सत्यापन
# Translated:  authentication
# Original:  V _ alidate
# ------------------------------
# 300
# Hindi: खाली
# Translated:  empty
# Original:  Idle
# ------------------------------
# 301
# Hindi: कोई विवरण नहीं
# Translated:  No Details
# Original:  No description
# ------------------------------
# 302
# Hindi: एटी-एसपीआई सत्यापक
# Translated:  AT - SPI Verifier
# Original:  AT - SPI Validator
# ------------------------------
# 303
# Hindi: अनुप्रयोग की पहुंचनीयता का सत्यापन करता है
# Translated:  Verifies the accessibility of the application
# Original:  Validates application accessibility
# ------------------------------
# 304
# Hindi: स्तर
# Translated:  level
# Original:  Level
# ------------------------------
# 305
# Hindi: भूमिका
# Translated:  role
# Original:  Role
# ------------------------------
# 306
# Hindi: सहेज रहे हैं
# Translated:  Saving
# Original:  Saving
# ------------------------------
# 307
# Hindi: पुष्टि कर रहे हैं
# Translated:  Confirming
# Original:  Validating
# ------------------------------
# 308
# Hindi: अपवाद
# Translated:  exception
# Original:  EXCEPT
# ------------------------------
# 309
# Hindi: त्रुटि
# Translated:  error
# Original:  ERROR
# ------------------------------
# 310
# Hindi: चेतावनी
# Translated:  warning
# Original:  WARN
# ------------------------------
# 311
# Hindi: सूचना
# Translated:  Information
# Original:  INFO
# ------------------------------
# 312
# Hindi: दोषमुक्त करें
# Translated:  Debug
# Original:  DEBUG
# ------------------------------
# 313
# Hindi: मूल
# Translated:  root
# Original:  Basic
# ------------------------------
# 314
# Hindi: मूलभूत जीयूआई अनुप्रयोग पहुंचनीयता का परीक्षण करता है
# Translated:  Tests the accessibility of the default GUI application
# Original:  Tests fundamental GUI application accessibility
# ------------------------------
# 315
# Hindi: % s जिस पर कार्रवाई हो सकती है, वह न तो फोकस करने योग्य है न ही चयनीय
# Translated:  % s on which action can be taken is neither focusable nor selective
# Original:  actionable% s is not focusable or selectable
# ------------------------------
# 316
# Hindi: अंतर्क्रियात्मक% s कार्रवाई करने योग्य नहीं है
# Translated:  Interactive% s is not actionable
# Original:  interactive% s is not actionable
# ------------------------------
# 317
# Hindi: एक से अधिक विडजेट फोकस में है
# Translated:  More than one widget is in focus
# Original:  more than one focused widget
# ------------------------------
# 318
# Hindi: % s का कोई पाठ अंतराफलक नहीं है
# Translated:  % s has no text interface
# Original:  % s has no text interface
# ------------------------------
# 319
# Hindi: अभिभावक में% s सूची शिशु सूची सेमेल नहीं खाती
# Translated:  The% s list in parent does not match the child list
# Original:  % s index in parent does not match child index
# ------------------------------
# 320
# Hindi: % s संबंध के लिए अन्योन्य गायब है
# Translated:  Other for% s relation missing
# Original:  Missing reciprocal for% s relation
# ------------------------------
# 321
# Hindi: % s गायब नाम या सूचक
# Translated:  % s missing name or indicator
# Original:  % s missing name or label
# ------------------------------
# 322
# Hindi: फोकस योग्य% s में सारणी अंतराफलक है, कोई चयनीय अंतराफलक नहीं हैbutton has focused state without focusable state
# Translated:  The focusable% s has a table interface, no selectable interface
# Original:  focusable% s has table interface, no selection interface
# ------------------------------
# 323
# Hindi: % s में% s स्थिति है, पर उसके साथ% s स्थिति नहीं है
# Translated:  % s has% s status, but does not have% s status with it
# Original:  % s has% s state without% s state
# ------------------------------
# 324
# Hindi: % s किसी समुच्चय का सदस्य नहीं है
# Translated:  % s is not a member of any set
# Original:  % s does not belong to a set
# ------------------------------
# 325
# Hindi: % (rolename) s सूची% (num) d पंक्ति और स्तंभ से मेल नहीं खातेparent indexrow and column index
# Translated:  % (rolename) s list% (num) d does not match row and column index
# Original:  % (rolename) s index% (num) d does not match row and column
# ------------------------------
# 326
# Hindi: % (rolename) s अभिभावक सूची% (num1) d पंक्ति और स्तंभ सूची% (num2) d से मेल नहीं खाते
# Translated:  % (rolename) s Parent list% (num1) d does not match line and column list% (num2) d
# Original:  % (rolename) s parent index% (num1) d does not match row and column index% (num2) d
# ------------------------------
# 327
# Hindi: % s का कोई नाम या विवरण नहीं
# Translated:  No name or description of% s
# Original:  % s has no name or description
# ------------------------------
# 328
# Hindi: पसंद (_ P)...
# Translated:  _ Bookmarks...
# Original:  _ Preferences...
# ------------------------------
# 329
# Hindi: विषय सूची (_ C)
# Translated:  _ Subject List
# Original:  _ Contents
# ------------------------------
# 330
# Hindi: एक्सेरसाइसर आपके डेस्कटोप में मौजूद अनुप्रयोग नहीं देख पाया। इस समस्या के समाधान के लिए आपको डेस्कटोप पहुंचनीयता को सक्रिय करना होगा। क्या आप इसे सक्रिय करना चाहते हैं?
# Translated:  Thexersizer could not find an application on your desktop. To solve this problem you must enable desktop accessibility. Do you want to enable it?
# Original:  Accerciser could not see the applications on your desktop. You must enable desktop accessibility to fix this problem. Do you want to enable it now?
# ------------------------------
# 331
# Hindi: टिप्पणीः परिवर्तन सत्रांत (लोगआउट) के बाद ही प्रभाव में आएंगे।
# Translated:  Note: Changes will only take effect after logout.
# Original:  Note: Changes only take effect after logout.
# ------------------------------
# 332
# Hindi: शिशु
# Translated:  child
# Original:  Children
# ------------------------------
# 333
# Hindi: पंजी ताजा करें (_ R)
# Translated:  _ Refresh Register
# Original:  _ Refresh Registry
# ------------------------------
# 334
# Hindi: सभी को ताजा करें
# Translated:  Refresh All
# Original:  Refresh all
# ------------------------------
# 335
# Hindi: आसंधि (नोड) को ताजा करें (_ N)
# Translated:  _ Refresh Protocols
# Original:  Refresh _ Node
# ------------------------------
# 336
# Hindi: चुनी गई आसंधियों (नोड) के शिशुओं को ताजा करें
# Translated:  Refresh the children of the selected nodes
# Original:  Refresh selected node 's children
# ------------------------------
# 337
# Hindi: घटक
# Translated:  component
# Original:  Component
# ------------------------------
# 338
# Hindi: कार्य
# Translated:  work
# Original:  Task
# ------------------------------
# 339
# Hindi: कुंजी
# Translated:  key
# Original:  Key
# ------------------------------
# 340
# Hindi: आल्ट
# Translated:  altar
# Original:  Alt
# ------------------------------
# 341
# Hindi: कंट्रोल
# Translated:  Control
# Original:  Ctrl
# ------------------------------
# 342
# Hindi: शिफ्ट
# Translated:  Shift
# Original:  Shift
# ------------------------------
# 343
# Hindi: ऊपरी पटल
# Translated:  top panel
# Original:  Top panel
# ------------------------------
# 344
# Hindi: निचला पटल
# Translated:  Lower Panel
# Original:  Bottom panel
# ------------------------------
# 345
# Hindi: एक्सेर्साइसर पसंद
# Translated:  Cursor Preferences
# Original:  accerciser Preferences
# ------------------------------
# 346
# Hindi: प्लगइन्स
# Translated:  Plugins
# Original:  Plugins
# ------------------------------
# 347
# Hindi: सार्वत्रिक फटाफट कुंजियां
# Translated:  Global FAT keys
# Original:  Global Hotkeys
# ------------------------------
# 348
# Hindi: हाइलाइटन
# Translated:  highlight
# Original:  Highlighting
# ------------------------------
# 349
# Hindi: हाइलाइट अवधिः
# Translated:  Highlight period:
# Original:  Highlight duration:
# ------------------------------
# 350
# Hindi: सीमांत रंगः
# Translated:  Border color:
# Original:  Border color:
# ------------------------------
# 351
# Hindi: हाइलाइट बक्से का सीमांत रंग
# Translated:  Limit color of the highlight box
# Original:  The border color of the highlight box
# ------------------------------
# 352
# Hindi: भराई का रंगः
# Translated:  Fill color:
# Original:  Fill color:
# ------------------------------
# 353
# Hindi: हाइलाइट बक्से का भराई रंग
# Translated:  Fill color of the highlight box
# Original:  The fill color of the highlight box
# ------------------------------
# 354
# Hindi: रविशंकर श्रीवास्तव (raviratlami @yahoo. com) राजेश रंजन (rajeshkajha @yahoo. com) ल. बालसुब्रमण्यम (l. balasubramaniam @gmail. com)
# Translated:  Rajeshkajha @ yahoo. com L. balasubramaniam @ gmail. com
# Original:  translator - credits
# ------------------------------
# 355
# Hindi: एक अंतर्क्रियात्मक पाइथन पहुंचनीयता अन्वेषक
# Translated:  An interactive Python accessibility explorer
# Original:  An interactive Python accessibility explorer
# ------------------------------
# 356
# Hindi: एक्सेर्साइसर सर्वाधिकार © 2006,2007 आईबीएम निगम (बीएसडी)
# Translated:  Copyright © 2006, 2007 IBM Corporation (BSD)
# Original:  accerciser Copyright © 2006, 2007 IBM Corporation (BSD)
# ------------------------------
# 357
# Hindi: नया बीएसडी लाइसेन्स विवरण के लिए देखिए प्रतिलिपीकरण और सूचना फाइलें
# Translated:  See copying and information files for new BSD license details
# Original:  The New BSD License See the COPYING and NOTICE files for details.
# ------------------------------
# 358
# Hindi: जाल स्थल
# Translated:  web site
# Original:  Web site
# ------------------------------
# 359
# Hindi: पसंद जोड़ें... (_ A)
# Translated:  _ Add Bookmarks...
# Original:  _ Add Bookmark...
# ------------------------------
# 360
# Hindi: चुने गए एक्सेसेबलों को पुस्तक-चिह्नित करें
# Translated:  Bookmark Selected Accessibility
# Original:  Bookmark selected accessible.
# ------------------------------
# 361
# Hindi: पुस्तक चिह्न संपादित करें (_ E)...
# Translated:  _ Edit Book Mark...
# Original:  _ Edit Bookmarks...
# ------------------------------
# 362
# Hindi: पुस्तक-चिह्नों को प्रबंधित करें।
# Translated:  Manage bookmarks.
# Original:  Manage bookmarks.
# ------------------------------
# 363
# Hindi: पुस्तक चिह्नों को संपादित करें...
# Translated:  Edit Book Marks...
# Original:  Edit Bookmarks...
# ------------------------------
# 364
# Hindi: शीर्षक
# Translated:  title
# Original:  Title
# ------------------------------
# 365
# Hindi: अनुप्रयोग
# Translated:  application
# Original:  Application
# ------------------------------
# 366
# Hindi: पथ
# Translated:  path
# Original:  Path
# ------------------------------
# 367
# Hindi: पुस्तक-चिह्न जोड़ें...
# Translated:  Add Bookmark...
# Original:  Add Bookmark...
# ------------------------------
# 368
# Hindi: शीर्षकः
# Translated:  Title:
# Original:  Title:
# ------------------------------
# 369
# Hindi: अनुप्रयोगः
# Translated:  Application:
# Original:  Application:
# ------------------------------
# 370
# Hindi: पथः
# Translated:  Path:
# Original:  Path:
# ------------------------------
# 371
# Hindi: प्लग-इन त्रुटियां
# Translated:  Plugin Errors
# Original:  Plugin Errors
# ------------------------------
# 372
# Hindi: दृश्य
# Translated:  view
# Original:  View
# ------------------------------
# 373
# Hindi: कोई दृश्य नहीं है
# Translated:  No View
# Original:  No view
# ------------------------------
# 374
# Hindi: एकल प्लग-इन दृश्य
# ...
# Original:  Selected Cell
# ------------------------------
# 882
# Hindi: सारणी (_ T)
# Translated:  _ Table
# Original:  _ Table
# ------------------------------
# 883
# Hindi: पाठ
# Translated:  text
# Original:  Text
# ------------------------------
# 884
# Hindi: ओफसेट
# Translated:  Offset
# Original:  Offset
# ------------------------------
# 885
# Hindi: डिफोल्टों को शामिल करें
# Translated:  Include defaults
# Original:  Include defaults
# ------------------------------
# 886
# Hindi: प्रारंभः 0
# Translated:  Start: 0
# Original:  Start: 0
# ------------------------------
# 887
# Hindi: अंतः 0
# Translated:  End 0
# Original:  End: 0
# ------------------------------
# 888
# Hindi: पाठ (_ x)
# Translated:  _ Text
# Original:  Te _ xt
# ------------------------------
# 889
# Hindi: मौजूदा मान
# Translated:  Current value
# Original:  Current value
# ------------------------------
# 890
# Hindi: न्यूनतम वृद्धि
# Translated:  minimum growth
# Original:  Minimum increment
# ------------------------------
# 891
# Hindi: अधिकतम मान
# Translated:  Maximum value
# Original:  Maximum value
# ------------------------------
# 892
# Hindi: न्यूनतम मान
# Translated:  Minimum value
# Original:  Minimum value
# ------------------------------
# 893
# Hindi: मान
# Translated:  value
# Original:  Val _ ue
# ------------------------------
# 894
# Hindi: अज्ञात
# Translated:  unknown
# Original:  unknown
# ------------------------------
# 895
# Hindi: अंतराफलक दर्शक
# Translated:  Interface Viewer
# Original:  Interface Viewer
# ------------------------------
# 896
# Hindi: अंतराफलक के विभिन्न गुणों को देखने देता है
# Translated:  Shows the various properties of the interface
# Original:  Allows viewing of various interface properties
# ------------------------------
# 897
# Hindi: (क्रियान्वित नहीं हुआ है)
# Translated:  (Not implemented)
# Original:  (not implemented)
# ------------------------------
# 898
# Hindi: नाम
# Translated:  name
# Original:  Name
# ------------------------------
# 899
# Hindi: यूआरआई
# Translated:  URI
# Original:  URI
# ------------------------------
# 900
# Hindi: प्रारंभ
# Translated:  start
# Original:  Start
# ------------------------------
# 901
# Hindi: अंत
# Translated:  end
# Original:  End
# ------------------------------
# 902
# Hindi: बहुत अधिक चयनीय शिशु हैं
# Translated:  Too many selectable babies
# Original:  Too many selectable children
# ------------------------------
# 903
# Hindi: (संशोधनीय)
# Translated:  (Amendable)
# Original:  (Editable)
# ------------------------------
# 904
# Hindi: तेज चुनाव
# Translated:  fast election
# Original:  Quick Select
# ------------------------------
# 905
# Hindi: प्लग-इन जिसमें हैं एक्सेसेबेलों को तेजी से चुनने के लिए कई विधियां
# Translated:  A plugin that contains several methods to quickly select execbels
# Original:  Plugin with various methods of selecting accessibles quickly.
# ------------------------------
# 906
# Hindi: अंतिम बार फोकस किए गए एक्सेसेबल को जांचें
# Translated:  Check last focused accessibility
# Original:  Inspect last focused accessible
# ------------------------------
# 907
# Hindi: माउस के अधीन जो एक्सेसेबल है, उसे जांचें
# Translated:  Check which is accessible under the mouse
# Original:  Inspect accessible under mouse
# ------------------------------
# 908
# Hindi: स्कीमाः
# Translated:  Schema:
# Original:  Sche _ ma:
# ------------------------------
# 909
# Hindi: सत्यापन
# Translated:  authentication
# Original:  V _ alidate
# ------------------------------
# 910
# Hindi: खाली
# Translated:  empty
# Original:  Idle
# ------------------------------
# 911
# Hindi: कोई विवरण नहीं
# Translated:  No Details
# Original:  No description
# ------------------------------
# 912
# Hindi: एटी-एसपीआई सत्यापक
# Translated:  AT - SPI Verifier
# Original:  AT - SPI Validator
# ------------------------------
# 913
# Hindi: अनुप्रयोग की पहुंचनीयता का सत्यापन करता है
# Translated:  Verifies the accessibility of the application
# Original:  Validates application accessibility
# ------------------------------
# 914
# Hindi: स्तर
# Translated:  level
# Original:  Level
# ------------------------------
# 915
# Hindi: भूमिका
# Translated:  role
# Original:  Role
# ------------------------------
# 916
# Hindi: सहेज रहे हैं
# Translated:  Saving
# Original:  Saving
# ------------------------------
# 917
# Hindi: पुष्टि कर रहे हैं
# Translated:  Confirming
# Original:  Validating
# ------------------------------
# 918
# Hindi: अपवाद
# Translated:  exception
# Original:  EXCEPT
# ------------------------------
# 919
# Hindi: त्रुटि
# Translated:  error
# Original:  ERROR
# ------------------------------
# 920
# Hindi: चेतावनी
# Translated:  warning
# Original:  WARN
# ------------------------------
# 921
# Hindi: सूचना
# Translated:  Information
# Original:  INFO
# ------------------------------
# 922
# Hindi: दोषमुक्त करें
# Translated:  Debug
# Original:  DEBUG
# ------------------------------
# 923
# Hindi: मूल
# Translated:  root
# Original:  Basic
# ------------------------------
# 924
# Hindi: मूलभूत जीयूआई अनुप्रयोग पहुंचनीयता का परीक्षण करता है
# Translated:  Tests the accessibility of the default GUI application
# Original:  Tests fundamental GUI application accessibility
# ------------------------------
# 925
# Hindi: % s जिस पर कार्रवाई हो सकती है, वह न तो फोकस करने योग्य है न ही चयनीय
# Translated:  % s on which action can be taken is neither focusable nor selective
# Original:  actionable% s is not focusable or selectable
# ------------------------------
# 926
# Hindi: अंतर्क्रियात्मक% s कार्रवाई करने योग्य नहीं है
# Translated:  Interactive% s is not actionable
# Original:  interactive% s is not actionable
# ------------------------------
# 927
# Hindi: एक से अधिक विडजेट फोकस में है
# Translated:  More than one widget is in focus
# Original:  more than one focused widget
# ------------------------------
# 928
# Hindi: % s का कोई पाठ अंतराफलक नहीं है
# Translated:  % s has no text interface
# Original:  % s has no text interface
# ------------------------------
# 929
# Hindi: अभिभावक में% s सूची शिशु सूची सेमेल नहीं खाती
# Translated:  The% s list in parent does not match the child list
# Original:  % s index in parent does not match child index
# ------------------------------
# 930
# Hindi: % s संबंध के लिए अन्योन्य गायब है
# Translated:  Other for% s relation missing
# Original:  Missing reciprocal for% s relation
# ------------------------------
# 931
# Hindi: % s गायब नाम या सूचक
# Translated:  % s missing name or indicator
# Original:  % s missing name or label
# ------------------------------
# 932
# Hindi: फोकस योग्य% s में सारणी अंतराफलक है, लेकिन कोई चयनीय अंतराफलक नहीं हैbutton has focused state without focusable state
# Translated:  The focusable% s has a table interface, but no selectable interface
# Original:  focusable% s has a table interface, but not a selection interface
# ------------------------------
# 933
# Hindi: % s में% s स्थिति है, पर उसके साथ% s स्थिति नहीं है
# Translated:  % s has% s status, but does not have% s status with it
# Original:  % s has% s state without% s state
# ------------------------------
# 934
# Hindi: % s किसी समुच्चय का सदस्य नहीं है
# Translated:  % s is not a member of any set
# Original:  % s does not belong to a set
# ------------------------------
# 935
# Hindi: % (rolename) s सूची% (num) d पंक्ति और स्तंभ से मेल नहीं खातेparent indexrow and column index
# Translated:  % (rolename) s list% (num) d does not match row and column index
# Original:  % (rolename) s index% (num) d does not match row and column
# ------------------------------
# 936
# Hindi: % (rolename) s अभिभावक सूची% (num1) d पंक्ति और स्तंभ सूची% (num2) d से मेल नहीं खाते
# Translated:  % (rolename) s Parent list% (num1) d does not match line and column list% (num2) d
# Original:  % (rolename) s parent index% (num1) d does not match row and column index% (num2) d
# ------------------------------
# 937
# Hindi: % s का कोई नाम या विवरण नहीं
# Translated:  No name or description of% s
# Original:  % s has no name or description
# ------------------------------
# 938
# Hindi: पसंद (_ P)...
# Translated:  _ Bookmarks...
# Original:  _ Preferences...
# ------------------------------
# 939
# Hindi: विषय सूची (_ C)
# Translated:  _ Subject List
# Original:  _ Contents
# ------------------------------
# 940
# Hindi: एक्सेरसाइसर आपके डेस्कटोप में मौजूद अनुप्रयोग नहीं देख पाया। इस समस्या के समाधान के लिए आपको डेस्कटोप पहुंचनीयता को सक्रिय करना होगा। क्या आप इसे सक्रिय करना चाहते हैं?
# Translated:  Thexersizer could not find an application on your desktop. To solve this problem you must enable desktop accessibility. Do you want to enable it?
# Original:  Accerciser could not see the applications on your desktop. You must enable desktop accessibility to fix this problem. Do you want to enable it now?
# ------------------------------
# 941
# Hindi: टिप्पणीः परिवर्तन सत्रांत (लोगआउट) के बाद ही प्रभाव में आएंगे।
# Translated:  Note: Changes will only take effect after logout.
# Original:  Note: Changes only take effect after logout.
# ------------------------------
# 942
# Hindi: <dead>
# Translated:  < dead >
# Original:  < dead >
# ------------------------------
# 943
# Hindi: शिशु
# Translated:  child
# Original:  Children
# ------------------------------
# 944
# Hindi: बच्चों के बिना अनुप्रयोग छिपाएँ/दिखाएँ (_ H)
# Translated:  _ Hide applications without children
# Original:  _ Hide / Show Applications without children
# ------------------------------
# 945
# Hindi: पंजी ताजा करें (_ R)
# Translated:  _ Refresh Register
# Original:  _ Refresh Registry
# ------------------------------
# 946
# Hindi: सभी को ताजा करें
# Translated:  Refresh All
# Original:  Refresh all
# ------------------------------
# 947
# Hindi: आसंधि (नोड) को ताजा करें (_ N)
# Translated:  _ Refresh Protocols
# Original:  Refresh _ Node
# ------------------------------
# 948
# Hindi: चुनी गई आसंधियों (नोड) के शिशुओं को ताजा करें
# Translated:  Refresh the children of the selected nodes
# Original:  Refresh selected node 's children
# ------------------------------
# 949
# Hindi: घटक
# Translated:  component
# Original:  Component
# ------------------------------
# 950
# Hindi: कार्य
# Translated:  work
# Original:  Task
# ------------------------------
# 951
# Hindi: कुंजी
# Translated:  key
# Original:  Key
# ------------------------------
# 952
# Hindi: आल्ट
# Translated:  altar
# Original:  Alt
# ------------------------------
# 953
# Hindi: कंट्रोल
# Translated:  Control
# Original:  Ctrl
# ------------------------------
# 954
# Hindi: शिफ्ट
# Translated:  Shift
# Original:  Shift
# ------------------------------
# 955
# Hindi: ऊपरी पटल
# Translated:  top panel
# Original:  Top panel
# ------------------------------
# 956
# Hindi: निचला पटल
# Translated:  Lower Panel
# Original:  Bottom panel
# ------------------------------
# 957
# Hindi: एक्सेर्साइसर पसंद
# Translated:  Cursor Preferences
# Original:  accerciser Preferences
# ------------------------------
# 958
# Hindi: प्लगइन्स
# Translated:  Plugins
# Original:  Plugins
# ------------------------------
# 959
# Hindi: सार्वत्रिक फटाफट कुंजियां
# Translated:  Global FAT keys
# Original:  Global Hotkeys
# ------------------------------
# 960
# Hindi: हाइलाइटन
# Translated:  highlight
# Original:  Highlighting
# ------------------------------
# 961
# Hindi: हाइलाइट अवधिः
# Translated:  Highlight period:
# Original:  Highlight duration:
# ------------------------------
# 962
# Hindi: सीमांत रंगः
# Translated:  Border color:
# Original:  Border color:
# ------------------------------
# 963
# Hindi: हाइलाइट बक्से का सीमांत रंग
# Translated:  Limit color of the highlight box
# Original:  The border color of the highlight box
# ------------------------------
# 964
# Hindi: भराई का रंगः
# Translated:  Fill color:
# Original:  Fill color:
# ------------------------------
# 965
# Hindi: हाइलाइट बक्से का भराई रंग
# Translated:  Fill color of the highlight box
# Original:  The fill color of the highlight box
# ------------------------------
# 966
# Hindi: रविशंकर श्रीवास्तव (raviratlami @yahoo. com) राजेश रंजन (rajeshkajha @yahoo. com) ल. बालसुब्रमण्यम (l. balasubramaniam @gmail. com)
# Translated:  Rajeshkajha @ yahoo. com L. balasubramaniam @ gmail. com
# Original:  translator - credits
# ------------------------------
# 967
# Hindi: एक अंतर्क्रियात्मक पाइथन पहुंचनीयता अन्वेषक
# Translated:  An interactive Python accessibility explorer
# Original:  An interactive Python accessibility explorer
# ------------------------------
# 968
# Hindi: एक्सेर्साइसर सर्वाधिकार (c) 2006,2007 आईबीएम निगम (बीएसडी)
# Translated:  Exchanger Copyright (c) 2006, 2007 IBM Corporation (BSD)
# Original:  accerciser Copyright (c) 2006, 2007 IBM Corporation (BSD)
# ------------------------------
# 969
# Hindi: नया बीएसडी लाइसेन्स विवरण के लिए देखिए प्रतिलिपीकरण और सूचना फाइलें
# Translated:  See copying and information files for new BSD license details
# Original:  The New BSD License See the COPYING and NOTICE files for details.
# ------------------------------
# 970
# Hindi: जाल स्थल
# Translated:  web site
# Original:  Web site
# ------------------------------
# 971
# Hindi: पसंद जोड़ें... (_ A)
# Translated:  _ Add Bookmarks...
# Original:  _ Add Bookmark...
# ------------------------------
# 972
# Hindi: चुने गए एक्सेसेबलों को पुस्तक-चिह्नित करें
# Translated:  Bookmark Selected Accessibility
# Original:  Bookmark selected accessible.
# ------------------------------
# 973
# Hindi: पुस्तक चिह्न संपादित करें (_ E)...
# Translated:  _ Edit Book Mark...
# Original:  _ Edit Bookmarks...
# ------------------------------
# 974
# Hindi: पुस्तक-चिह्नों को प्रबंधित करें।
# Translated:  Manage bookmarks.
# Original:  Manage bookmarks.
# ------------------------------
# 975
# Hindi: पुस्तक चिह्नों को संपादित करें...
# Translated:  Edit Book Marks...
# Original:  Edit Bookmarks...
# ------------------------------
# 976
# Hindi: शीर्षक
# Translated:  title
# Original:  Title
# ------------------------------
# 977
# Hindi: अनुप्रयोग
# Translated:  application
# Original:  Application
# ------------------------------
# 978
# Hindi: पथ
# Translated:  path
# Original:  Path
# ------------------------------
# 979
# Hindi: पुस्तक-चिह्न जोड़ें...
# Translated:  Add Bookmark...
# Original:  Add Bookmark...
# ------------------------------
# 980
# Hindi: शीर्षकः
# Translated:  Title:
# Original:  Title:
# ------------------------------
# 981
# Hindi: अनुप्रयोगः
# Translated:  Application:
# Original:  Application:
# ------------------------------
# 982
# Hindi: पथः
# Translated:  Path:
# Original:  Path:
# ------------------------------
# 983
# Hindi: प्लग-इन त्रुटियांviewport
# Translated:  Plugin Errors
# Original:  Plugin Errors
# ------------------------------
# 984
# Hindi: दृश्य
# Translated:  view
# Original:  View
# ------------------------------
# 985
# Hindi: कोई दृश्य नहीं है
# Translated:  No View
# Original:  No view
# ------------------------------
# 986
# Hindi: एकल प्लग-इन दृश्य
# Translated:  Single Plugin View
# Original:  _ Single plugins view
# ------------------------------
# 987
# Hindi: प्लग-इन दृश्य
# Translated:  Plugin View
# Original:  Plugin View
# ------------------------------
# 988
# Hindi: प्लग-इन दृश्य (% d)
# Translated:  Plugin View (% d)
# Original:  Plugin View (% d)
# ------------------------------
# 989
# Hindi: नया दृश्य... (_ N)
# Translated:  _ New View...
# Original:  _ New view...
# ------------------------------
# 990
# Hindi: नया दृश्य...
# Translated:  New View...
# Original:  New View...
# ------------------------------
# 991
# Hindi: फाइल (F)
# Translated:  & Files
# Original:  _ File
# ------------------------------
# 992
# Hindi: संपादित करेंmenu
# Translated:  Edit
# Original:  _ Edit
# ------------------------------
# 993
# Hindi: पसंद (_ B) menu
# Translated:  _ Bookmarks
# Original:  _ Bookmarks
# ------------------------------
# 994
# Hindi: दृश्य _ (V)
# Translated:  _ View
# Original:  _ View
# ------------------------------
# 995
# Hindi: मदद
# Translated:  help
# Original:  _ Help
# ------------------------------
# 996
# Hindi: एक्सेर्साइसर
# Translated:  exacerbate
# Original:  Accerciser
# ------------------------------
# 997
# Hindi: अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# Translated:  Benefit your application from accessibility exercises
# Original:  Give your application an accessibility workout
# ------------------------------
# 998
# Hindi: एक्सेर्साइसर पहुंचनीयता अन्वेषक
# Translated:  Cursor Accessibility Explorer
# Original:  Accerciser Accessibility Explorer
# ------------------------------
# 999
# Hindi: उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# Translated:  List of plugins that have been disabled by default
# Original:  A list of plugins that are disabled by default
# ------------------------------
# 1000
# Hindi: उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# Translated:  List of plugins that have been disabled by default
# Original:  A list of plugins that are disabled by default.
# ------------------------------

# %%
# BLEU Score
import nltk
from nltk.translate.bleu_score import corpus_bleu
references = [[eng] for eng in english_sentences]  # Create reference list of lists
candidates = translatedHinEng  # Model translations
bleu_score = corpus_bleu(references, candidates)
print(f"BLEU score: {bleu_score:.4f}")
# Out:
# BLEU score: 0.6810

# %%
# STS Score

# !pip install sentence-transformers

# STS Score using SentenceTransformer
from sentence_transformers import SentenceTransformer, util
import torch

# Load the pre-trained model
model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
model = model.to('cuda' if torch.cuda.is_available() else 'cpu')

# Encode the original Hindi sentences and the translated sentences
embeddings1 = model.encode(english_sentences, convert_to_tensor=True, device=model.device)
embeddings2 = model.encode(translatedHinEng, convert_to_tensor=True, device=model.device)

# Compute cosine similarities between the embeddings
cosine_scores = util.cos_sim(embeddings1, embeddings2)

# Calculate the average STS score
sts_score = cosine_scores.diag().mean().item()
print(f"STS score: {sts_score:.4f}")
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.42.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.4.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.3.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 15.7 MB/s eta 0:00:00
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-3.0.1
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.12k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# STS score: 0.8299

# %%
# CHRF Score
# !pip install sacrebleu
from sacrebleu.metrics import CHRF

# Initialize CHRF metric
chrf = CHRF(word_order=1)

# Calculate CHRF score
chrf_score = chrf.corpus_score(translatedHinEng, [english_sentences]).score
print(f"CHRF score: {chrf_score:.4f}")
# Out:
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.10/dist-packages (2.4.3)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2.10.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2024.5.15)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (1.26.4)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (4.9.4)
# CHRF score: 63.2635

# %%
# METEOR Score
import nltk
from nltk.translate.meteor_score import meteor_score

# Download required NLTK data (if not already downloaded)
nltk.download('punkt')
nltk.download('wordnet')

# Tokenize the sentences if they're not already tokenized
english_sentences_tokenized = [nltk.word_tokenize(sent) for sent in english_sentences]
translatedHinEng_tokenized = [nltk.word_tokenize(sent) for sent in translatedHinEng]

# Calculate METEOR score
meteor_scores = [meteor_score([ref], hyp) for ref, hyp in zip(english_sentences_tokenized, translatedHinEng_tokenized)]
average_meteor_score = sum(meteor_scores) / len(meteor_scores)

print(f"METEOR score: {average_meteor_score:.4f}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# METEOR score: 0.5603

# %%
import nltk
from nltk.lm import KneserNeyInterpolated
from nltk.lm.preprocessing import padded_everygram_pipeline
from nltk.util import ngrams
import numpy as np

# Download necessary NLTK data
nltk.download('punkt')

def train_model(sentences, n=2):
    tokenized = [['<s>'] + list(map(str.lower, nltk.word_tokenize(sent))) + ['</s>'] for sent in sentences]
    train_data, padded_vocab = padded_everygram_pipeline(n, tokenized)
    model = KneserNeyInterpolated(n)
    model.fit(train_data, padded_vocab)
    return model

def calculate_perplexity(model, sentences, n=2):
    perplexities = []
    for sent in sentences:
        tokens = ['<s>'] + list(map(str.lower, nltk.word_tokenize(sent))) + ['</s>']
        test_data = list(ngrams(tokens, n))
        try:
            pp = model.perplexity(test_data)
            perplexities.append(pp)
        except ValueError:
            pass  # Skip sentences that cause errors
    return np.mean(perplexities) if perplexities else float('inf')

# Train models
english_model = train_model(english_sentences)
hindi_model = train_model(translatedHinEng)

# Calculate perplexities
english_perplexity = calculate_perplexity(english_model, english_sentences)
hindi_perplexity = calculate_perplexity(hindi_model, translatedHinEng)

print(f"English Perplexity: {english_perplexity:.4f}")
print(f"Translated hindi Perplexity: {hindi_perplexity:.4f}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# English Perplexity: 11.4865
# Translated hindi Perplexity: 11.7331
